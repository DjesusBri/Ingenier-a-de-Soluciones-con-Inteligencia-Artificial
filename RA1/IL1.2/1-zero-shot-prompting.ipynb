# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/Mistral/RA1/IL1.2/1-zero-shot-prompting.ipynb)

# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.mistral.ai/v1")
    os.environ.setdefault("LLM_MODEL", "mistral-small-latest")
    os.environ.setdefault("LLM_MODEL_SMALL", "ministral-8b-latest")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage, SystemMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto."
    
    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"
    
    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto. 
    
Tarea: Analiza el sentimiento del siguiente texto sobre un producto.
    
Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]
    
Texto a analizar: "{texto}"""
    
    print("=== COMPARACIÓN DE PROMPTS ===")
    
    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n" + "-"*60)
    
    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")
    
    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: El texto es una **reseña breve y subjetiva** sobre un nuevo modelo de iPhone. Presenta tanto aspectos positivos como negativos, lo que refleja un **equilibrio en la valoración**. Aquí hay un análisis detallado:
#
# ### **1. Estructura y contenido**
# - **Estructura simple**: Dos oraciones que destacan virtudes y un defecto.
# - **Enfoque en características clave**:
#   - **Batería**: Se describe como "increíble" (exageración subjetiva).
#   - **Cámara**: "Fantástica" (término emocional, no técnico).
#   - **Precio**: "Muy alto" (juicio negativo basado en percepción personal).
#
# ### **2. Lenguaje y estilo**
# - **Adjetivos valorativos**: Usa términos como "increíble", "fantástica" y "alto", que expresan opiniones, no hechos objetivos.
# - **Contraste**: La estructura "A pero B" (elipsis de "aunque") es común en reseñas para presentar pros y contras.
# - **Brevedad**: Ideal para redes sociales o mensajes rápidos, pero superficial para análisis profundos.
#
# ### **3. Perspectiva y tono**
# - **Tono positivo-negativo**: Equilibrado, pero con énfasis en la crítica al precio.
# - **Subjetividad**: No hay datos técnicos ni comparaciones (ej.: "mejor que el modelo anterior").
#
# ### **4. Posibles intenciones**
# - **Informar**: Dar una primera impresión sobre el dispositivo.
# - **Opinar**: Influir en la percepción del lector (ej.: "vale la pena?").
# - **Generar debate**: Invitar a comparar con otros smartphones.
#
# ### **5. Mejoras posibles**
# Para hacerlo más útil, el texto podría:
# - **Añadir detalles técnicos**: Ej.: "La batería dura 24 horas con uso moderado".
# - **Comparar**: "Supera a la cámara del Samsung Galaxy S23 en condiciones de poca luz".
# - **Contextualizar**: "El precio es alto, pero justificado por el ecosistema Apple".
#
# ### **Conclusión**
# Es una opinión **breve y personal**, útil para decisiones rápidas, pero limitada en profundidad. Si se busca un análisis más riguroso, se necesitarían datos objetivos y comparaciones.
#
# ¿Te gustaría profundizar en algún aspecto en particular?
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto sobre ...
# Respuesta: - **Sentimiento general:** Neutral (mezcla de aspectos positivos y negativos)
# - **Aspectos positivos:**
#   - Batería increíble.
#   - Cámara fantástica.
# - **Aspectos negativos:**
#   - Precio muy alto.
# - **Puntuación de confianza:** 9 (el texto expresa claramente opiniones positivas y negativas con un tono equilibrado).
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")
    
    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]
    
    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.
    
Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""
    
    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")
    
    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.
    
Tarea: Crear un post para LinkedIn sobre el tema dado.
    
Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement
    
Tema: "Importancia del aprendizaje continuo en tecnología"
    
Post para LinkedIn:"""
    
    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)
        
        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')
        
        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# **"¿Estás aprovechando el ritmo acelerado de la tecnología o te está dejando atrás?"**
#
# En un mundo donde la innovación avanza a velocidad luz, el aprendizaje continuo ya no es un *plus*, sino una necesidad. La tecnología no espera, y quienes se estancan en "lo que sabían ayer" pierden oportunidades clave.
#
# Pero aquí está la buena noticia: **el conocimiento no tiene fecha de caducidad**. Plataformas como cursos online, webinars o comunidades especializadas te permiten actualizarte sin frenar tu productividad. La pregunta es: ¿qué habilidad tecnológica aprenderás este trimestre para mantener tu ventaja competitiva?
#
# 💡 *Innovación = Aprendizaje constante + Acción.*
#
# #Tecnología #AprendizajeContinuo
# ----------------------------------------
#
# Análisis:
# • Palabras: 101 (límite: 150)
# • Hashtags: 2
# • Preguntas: 2
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")
    
    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores 
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los 
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5 
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento 
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron 
    3.2% tras el anuncio."""
    
    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.
    
Extrae la siguiente información del texto dado:
    
Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}
    
Texto: "{texto_noticia}"
    
JSON:"""
    
    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)
        
        # Intentar parsear como JSON para validar formato
        import json
        try:
            data = json.loads(response.content)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")
            
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# ```json
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
# ```
#
# ✗ Formato JSON inválido - necesita refinamiento del prompt

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")
    
    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"
    
    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }
    
    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"
        
        print(f"\n{rol.upper()}:")
        print("-" * 30)
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")
    
    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# Mejorar el rendimiento de una aplicación web es un proceso que implica optimizar múltiples aspectos, desde el frontend hasta el backend, la infraestructura y la experiencia de usuario. Aquí tienes una...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# ¡Excelente pregunta! Como desarrollador senior con una década de experiencia en optimización web, te daré un enfoque **sistémico y priorizado** para mejorar el rendimiento de tu aplicación. Vamos a di...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# Mejorar el rendimiento de una aplicación web requiere un enfoque **multidimensional** que abarque desde la optimización del **frontend** hasta la infraestructura del **backend**, pasando por la gestió...
#
# CTO:
# ------------------------------
# Como **CTO** de una startup tecnológica, entiendo que mejorar el rendimiento de una aplicación web no es solo un tema técnico, sino una **estrategia de negocio**. Un rendimiento óptimo impacta directa...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")
    
    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"
    
    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.
    
Problema: {problema}
    
Desarrolla una estrategia siguiendo este proceso paso a paso:
    
PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app
    
PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección
    
PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación
    
PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición
    
Desarrolla cada paso con detalle:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)
        
        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())
        
        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# **Estrategia de Marketing Digital para el Lanzamiento de una App de Fitness**
# *(Enfoque: Adquisición de usuarios + Retención + Monetización)*
#
# ---
#
# ## **PASO 1: Análisis Inicial**
#
# ### **Público Objetivo (Segmentación detallada)**
# **1. Personas fitness motivadas por resultados rápidos**
# - **Demografía**: Hombres y mujeres de 25–45 años, ingresos medios-altos ($30K–$100K anuales).
# - **Psicografía**: Buscan eficiencia (ejercicios en poco tiempo), seguimiento de progreso y comunidad.
# - **Comportamiento**: Consumen contenido en Instagram/TikTok, siguen influencers de fitness, pagan por apps premium (MyFitnessPal, Strava).
# - **Dolor**: Frustración con apps genéricas que no se adaptan a sus objetivos (ej. ganar músculo vs. perder grasa).
#
# **2. Principiantes que buscan hábitos sostenibles**
# - **Demografía**: 18–35 años, estudiantes o jóvenes profesionales.
# - **Psicografía**: Quieren evitar lesiones, necesitan guía paso a paso y motivación.
# - **Comportamiento**: Buscan en Google "rutina de ejercicios para principiantes", consumen contenido en YouTube y Reddit (r/Fitness).
# - **Dolor**: Falta de conocimiento y miedo al fracaso.
#
# **3. Comunidades específicas (nicho)**
# - **Atletas recreativos**: Corredores, ciclistas o crossfitters que buscan optimizar su entrenamiento.
# - **Padres ocupados**: Mujeres/madres que no tienen tiempo para ir al gimnasio.
# - **Personas con lesiones**: Buscan rehabilitación o ejercicios de bajo impacto.
#
# **Segmentación por valor de cliente (LTV)**:
# - **Alto**: Atletas recreativos y profesionales (suscripción premium).
# - **Medio**: Personas con ingresos medios que pagan por planes mensuales.
# - **Bajo**: Estudiantes (freemium con ads o descuentos).
#
# ---
#
# ### **3 Puntos de Valor Únicos (USP)**
# 1. **Personalización con IA**
#    - La app usa algoritmos para generar rutinas **100% adaptadas** a:
#      - Objetivos (pérdida de grasa, hipertrofia, resistencia).
#      - Equipo disponible (sin gimnasio, solo bandas, etc.).
#      - Historial de lesiones o limitaciones físicas.
#    - *Ejemplo*: "Tu plan de 4 semanas para ganar 3kg de músculo en casa".
#
# 2. **Gamificación + Comunidad Social**
#    - **Sistema de recompensas**: Badges por retos (ej. "7 días consecutivos de entrenamiento"), rankings con amigos.
#    - **Feed social**: Los usuarios pueden compartir progresos (fotos/videos) y competir en desafíos semanales.
#    - *Diferencial*: Combina lo individual (IA) con lo colectivo (red social).
#
# 3. **Feedback en tiempo real con wearables**
#    - Integración con **Apple Watch, Garmin, Whoop** para:
#      - Ajustar la intensidad del entrenamiento según la frecuencia cardíaca.
#      - Alertas si el usuario no duerme lo suficiente (recomendación de descanso activo).
#    - *Ventaja*: Reduce la fricción vs. apps que requieren ingresar datos manualmente.
#
# **Bonus USP (para viralidad)**:
# - **"Desafío de 30 días"** con premios reales (ej. membresías gratis, descuentos en suplementos).
#
# ---
#
# ## **PASO 2: Canales de Marketing Digital**
#
# | **Canal**          | **Justificación**                                                                 | **Presupuesto sugerido** |
# |---------------------|-------------------------------------------------------------------------------|-------------------------|
# | **1. TikTok/Reels (Meta + Instagram)** | - **Alcance masivo**: El 60% de los usuarios de fitness consume contenido en formato vertical. <br> - **Algoritmo favorable**: Los videos de "before/after", rutinas rápidas o "fails" tienen alto engagement. <br> - **Conversión directa**: Enlace en bio para descarga + ads segmentadas. | 30–40% del presupuesto |
# | **2. YouTube (Largos + Shorts)** | - **Educación + SEO**: Videos como "Cómo hacer sentadillas correctamente" o "Rutina de 10 minutos para glúteos" posicionan la app como autoridad. <br> - **Monetización**: Colaboraciones con creadores de fitness (ej. Athlean-X, Chloe Ting). | 20–25% |
# | **3. Influencers Micro/Nano (TikTok, IG, Twitch)** | - **Autenticidad**: Los microinfluencers (10K–100K seguidores) tienen engagement del 5–15% (vs. 1–3% de los macro). <br> - **Nicho**: Buscar creadores de nicho (ej. fitness para oficinistas, madres, runners). <br> - **Formato**: Unboxings, tutoriales con la app, retos. | 25–30% |
# | **4. Google Ads + SEO** | - **Intención de búsqueda**: Palabras clave como "mejor app de fitness 2024", "rutinas en casa sin equipo". <br> - **Landing pages optimizadas**: Para conversiones (ej. "Descarga gratis y prueba 7 días"). <br> - **Retargeting**: Usuarios que abandonan el carrito. | 15–20% |
# | **5. Reddit + Foros Especializados** | - **Comunidades activas**: Subreddits como r/Fitness, r/HomeGym, r/BodyweightFitness. <br> - **Estrategia**: Responder preguntas con valor (no spam) y mencionar la app como "solución". <br> - **AMAs (Ask Me Anything)**: Con el fundador o un entrenador certificado. | 5–10% |
#
# **Canales secundarios (para escalar)**:
# - **Email Marketing**: Secuencia de onboarding para retener usuarios (ej. "Tu primer entrenamiento en 3 días").
# - **Twitch**: Streams en vivo con entrenadores (ej. "Entrena conmigo en directo").
# - **LinkedIn**: Para B2B (ej. alianzas con gimnasios o empresas de bienestar corporativo).
#
# ---
#
# ## **PASO 3: Estrategia de Contenido**
#
# ### **Tipos de Contenido por Canal**
#
# | **Canal**          | **Formato de Contenido**                                                                 | **Frecuencia**       | **Objetivo**                          |
# |---------------------|-----------------------------------------------------------------------------------------|----------------------|---------------------------------------|
# | **TikTok/Reels**    | - Videos cortos (15–30 seg): "3 ejercicios para abdominales en 1 minuto". <br> - "Antes/Después" de usuarios reales. <br> - Challenges virales (ej. #7DaySquatChallenge). <br> - Behind-the-scenes (desarrollo de la IA, equipo). | 3–5 posts/semana     | **Awareness + Engagement**            |
# | **YouTube**         | - Tutoriales largos (10–20 min): "Rutina completa para principiantes". <br> - Reviews de equipos (ej. "¿Vale la pena la banda de resistencia X?"). <br> - Episodios en serie (ej. "Transformación de 30 días"). | 1–2 videos/semana    | **Autoridad + SEO**                   |
# | **Influencers**     | - Unboxings de la app. <br> - Retos personales con seguimiento en vivo. <br> - Stories con enlaces directos. | 2–4 colaboraciones/mes | **Conversión + Credibilidad**         |
# | **Google Ads**      | - Landing pages con: <br>   - Video testimonial. <br>   - CTA claro ("Prueba 7 días gratis"). <br>   - Social proof (reviews de usuarios). | Campañas continuas   | **Descargas + Leads**                 |
# | **Reddit/Foros**    | - Guías detalladas (ej. "Cómo empezar en fitness sin lesionarte"). <br> - AMA con expertos. <br> - Comentarios útiles (no spam). | 2–3 posts/semana     | **Trust + Tráfico orgánico**          |
#
# ### **Calendario de Contenido (Primeros 3 Meses)**
# | **Mes** | **Enfoque**               | **Ejemplo de Contenido**                                                                 |
# |---------|---------------------------|-----------------------------------------------------------------------------------------|
# | **Mes 1** | Lanzamiento + Awareness   | - TikTok: "¡Descubre la app que adapta tus entrenamientos con IA!" (video viral). <br> - YouTube: "¿Por qué la mayoría de apps de fitness fallan?". <br> - Influencers: Unboxing con 5 microinfluencers. |
# | **Mes 2** | Engagement + Retención    | - TikTok: Challenge #30DayFitness con premios. <br> - YouTube: "Cómo usar la IA para crear tu rutina perfecta". <br> - Reddit: AMA con un nutricionista. |
# | **Mes 3** | Conversión + Monetización | - Google Ads: Campaña de retargeting para usuarios que descargaron pero no usaron la app. <br> - Email: "Tu progreso en la app vs. la media de usuarios". |
#
# ---
#
# ## **PASO 4: Métricas y KPIs**
#
# ### **5 Métricas Clave**
# | **KPI**                     | **Definición**                                                                 | **Meta (Primeros 6 meses)** |
# |-----------------------------|-------------------------------------------------------------------------------|----------------------------|
# | **1. Tasa de Descarga (CAC)** | Costo por adquisición de usuario (gasto en ads / número de descargas).       | <$5 USD por descarga       |
# | **2. Retención D7 (Día 7)**  | % de usuarios que abren la app al menos una vez en los primeros 7 días.       | 40–50%                     |
# | **3. Engagement (DAU/MAU)**  | Usuarios activos diarios vs. mensuales.                                      | DAU: 20% de MAU            |
# | **4. Lifetime Value (LTV)**  | Ingresos promedio por usuario durante su vida en la app.                      | LTV: 3x el CAC             |
# | **5. Net Promoter Score (NPS)** | Satisfacción del usuario (encuesta post-uso).                                | NPS > 50                   |
#
# ### **Herramientas de Medición**
# | **Herramienta**       | **Uso**                                                                       |
# |-----------------------|-------------------------------------------------------------------------------|
# | **Google Analytics 4** | Seguimiento de tráfico web, conversiones y embudos de descarga.              |
# | **Firebase/Amplitude** | Analítica de app (retención, eventos como "rutina completada").               |
# | **Mixpanel**          | Profundizar en el comportamiento del usuario (ej. qué características usan más). |
# | **Hotjar**            | Grabaciones de sesiones para identificar puntos de fricción en la app.        |
# | **Meta Ads Manager**  | Métricas de campañas en Facebook/Instagram (CAC, ROAS).                      |
# | **TikTok Ads Manager** | Rendimiento de ads en TikTok (CTR, conversiones).                            |
# | **Reddit Analytics**  | Tráfico orgánico desde foros y engagement en posts.                           |
# | **Stripe/RevenueCat** | Ingresos por suscripciones y monetización (IAPs).                             |
#
# ### **Dashboard Recomendado (Ejemplo)**
# *(Herramienta: Google Data Studio o Looker Studio)*
# - **Pestaña 1**: Adquisición (CAC por canal, descargas, tráfico).
# - **Pestaña 2**: Engagement (DAU, retención, eventos clave).
# - **Pestaña 3**: Monetización (LTV, ARPU, conversión a premium).
# - **Pestaña 4**: Feedback (NPS, reviews en App Store/Play Store).
#
# ---
#
# ### **Recomendaciones Finales**
# 1. **Prueba A/B**: Testear diferentes creativos en ads (ej. video vs. carrusel en Meta).
# 2. **Escalar lo que funciona**: Si TikTok tiene un CAC bajo, aumentar presupuesto allí.
# 3. **Feedback loop**: Usar datos de la app para mejorar el producto (ej. si muchos usuarios abandonan en el día 3, ajustar el onboarding).
# 4. **Alianzas estratégicas**: Colaborar con marcas de suplementos o wearables para cross-promoción.
#
# **Kickoff sugerido**:
# - **Semana 1–2**: Crear perfiles en redes, grabar contenido base, lanzar campañas de prueba.
# - **Semana 3–4**: Primeras colaboraciones con influencers, optimizar landing pages.
# - **Mes 2**: Lanzar el desafío viral y escalar lo que funcione.
#
# ¿Necesitas profundizar en algún área específica (ej. estructura de ads, guión para influencers)?
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")
    
    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''
    
    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.
    
Analiza el siguiente código y proporciona:
    
1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?
    
2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento
    
3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores
    
4. PUNTUACIÓN DE CALIDAD: [1-10]
    
Código a analizar:
```python
{codigo_ejemplo}
```
    
Análisis:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# ### **Análisis del Código: `process_user_data`**
#
# ---
#
# ## **1. FUNCIONALIDAD**
# ### **¿Qué hace este código?**
# - La función `process_user_data` recibe una lista de diccionarios (`users`), donde cada diccionario representa un usuario con al menos las claves `"age"`, `"name"` y `"email"`.
# - **Filtra** a los usuarios mayores de 18 años (`age > 18`).
# - **Transforma** los datos de estos usuarios:
#   - Convierte el nombre a mayúsculas (`name.upper()`).
#   - Mantiene el email sin modificar.
#   - Asigna el estado `"adult"`.
# - **Devuelve** una lista de diccionarios con los usuarios procesados.
#
# ### **Propósito**
# - **Filtrar y transformar datos de usuarios** para obtener un subconjunto de usuarios adultos con sus nombres en mayúsculas y un estado explícito.
# - Podría ser parte de un pipeline de procesamiento de datos (ej: generación de reportes, envío de emails a adultos, etc.).
#
# ---
#
# ## **2. PROBLEMAS POTENCIALES**
#
# ### **⚠️ Errores de Lógica**
# 1. **Falta de validación de claves en el diccionario**:
#    - Si algún usuario no tiene las claves `"age"`, `"name"` o `"email"`, el código lanzará un `KeyError`.
#    - Ejemplo: `user = {"age": 20, "name": "Alice"}` → Fallará al acceder a `"email"`.
#
# 2. **Tipado dinámico y problemas de tipo**:
#    - No hay verificación de que `"age"` sea un número (`int` o `float`). Si es un string (ej: `"25"`), la comparación `> 18` funcionará, pero si es un string no numérico (ej: `"twenty"`), generará un `TypeError`.
#    - No hay validación de que `"name"` sea un string (podría ser `None` o un número).
#
# 3. **Lógica de filtrado restrictiva**:
#    - Solo devuelve usuarios con `age > 18`. ¿Qué pasa con usuarios exactamente de 18 años? ¿Deberían incluirse? Depende del requisito de negocio.
#
# 4. **Caso de usuarios con `age` faltante o `None`**:
#    - Si `user["age"]` es `None`, la comparación `None > 18` lanzará un `TypeError`.
#
# ---
#
# ### **🔒 Vulnerabilidades de Seguridad**
# 1. **Inyección de datos maliciosos**:
#    - Si los nombres de usuarios provienen de una fuente no confiable (ej: formulario web), no hay sanitización de datos. Aunque en este caso solo se usa `.upper()`, en otros contextos podría ser un riesgo.
#
# 2. **Exposición de emails**:
#    - Los emails se incluyen sin cifrado ni anonimización, lo que podría ser un problema de privacidad si los datos se almacenan o transmiten.
#
# ---
#
# ### **⚡ Problemas de Rendimiento**
# 1. **Ineficiencia en la construcción de diccionarios**:
#    - Se crea un nuevo diccionario para cada usuario, lo que puede ser costoso en memoria si `users` es muy grande.
#    - Alternativa: Usar comprensiones de listas (más eficientes en Python).
#
# 2. **Falta de manejo de grandes volúmenes de datos**:
#    - No hay soporte para procesamiento por lotes (batch processing), lo que podría ser necesario si `users` tiene millones de registros.
#
# ---
#
# ## **3. MEJORAS SUGERIDAS**
#
# ### **🔧 Optimizaciones de Código**
# 1. **Usar comprensión de listas** (más idiomático en Python):
#    ```python
#    def process_user_data(users):
#        return [
#            {
#                "name": user["name"].upper(),
#                "email": user["email"],
#                "status": "adult"
#            }
#            for user in users
#            if user.get("age", 0) > 18  # Usar .get() para evitar KeyError
#            and isinstance(user.get("name"), str)  # Validar tipo de nombre
#            and isinstance(user.get("email"), str)  # Validar tipo de email
#        ]
#    ```
#
# 2. **Validación explícita de tipos**:
#    ```python
#    if not isinstance(user.get("age"), (int, float)):
#        continue  # O manejar el error según el caso de uso
#    ```
#
# 3. **Manejo de casos edge**:
#    - ¿Qué hacer si `age` es `None` o no es un número? Ejemplo:
#      ```python
#      age = user.get("age")
#      if age is None or not isinstance(age, (int, float)):
#          continue  # Saltar usuarios inválidos
#      ```
#
# 4. **Parámetros por defecto para claves faltantes**:
#    - Usar `.get()` con valores por defecto para evitar `KeyError`:
#      ```python
#      age = user.get("age", 0)  # Si no existe, asume 0 (menor de edad)
#      ```
#
# ---
#
# ### **📌 Mejores Prácticas**
# 1. **Documentación**:
#    - Añadir un docstring para clarificar el propósito y los parámetros:
#      ```python
#      def process_user_data(users: list[dict]) -> list[dict]:
#          """
#          Filtra usuarios mayores de 18 años y transforma sus datos.
#
#          Args:
#              users: Lista de diccionarios con claves "age", "name" y "email".
#
#          Returns:
#              Lista de usuarios adultos con nombre en mayúsculas y estado "adult".
#
#          Raises:
#              ValueError: Si algún usuario tiene datos inválidos (ej: age no numérico).
#          """
#      ```
#
# 2. **Validación de entrada**:
#    - Verificar que `users` sea una lista:
#      ```python
#      if not isinstance(users, list):
#          raise TypeError("users debe ser una lista")
#      ```
#
# 3. **Tipado estático (opcional)**:
#    - Usar `typing` para mayor claridad:
#      ```python
#      from typing import List, Dict, Any
#
#      def process_user_data(users: List[Dict[str, Any]]) -> List[Dict[str, str]]:
#      ```
#
# 4. **Manejo de errores**:
#    - Lanzar excepciones específicas para casos inválidos:
#      ```python
#      if "name" not in user:
#          raise ValueError("Falta la clave 'name' en el usuario")
#      ```
#
# 5. **Funciones auxiliares**:
#    - Separar la lógica de validación en una función aparte para reutilización:
#      ```python
#      def is_valid_user(user: dict) -> bool:
#          return (
#              "age" in user
#              and isinstance(user["age"], (int, float))
#              and user["age"] > 18
#              and "name" in user
#              and isinstance(user["name"], str)
#              and "email" in user
#              and isinstance(user["email"], str)
#          )
#      ```
#
# ---
#
# ### **🛡️ Manejo de Errores**
# 1. **Excepciones personalizadas**:
#    ```python
#    class InvalidUserDataError(ValueError):
#        pass
#
#    # En la función:
#    if not isinstance(user.get("age"), (int, float)):
#        raise InvalidUserDataError(f"Edad inválida para el usuario {user.get('name')}")
#    ```
#
# 2. **Manejo de casos edge**:
#    - Si `age` es `None`, decidir si se salta el usuario o se asigna un valor por defecto:
#      ```python
#      age = user.get("age")
#      if age is None:
#          continue  # O asignar un valor por defecto
#      ```
#
# 3. **Logging (para debugging)**:
#    - Registrar errores para depuración:
#      ```python
#      import logging
#      logging.basicConfig(level=logging.ERROR)
#
#      try:
#          # Código...
#      except KeyError as e:
#          logging.error(f"Falta clave en usuario: {e}")
#      ```
#
# ---
#
# ## **4. PUNTUACIÓN DE CALIDAD: [6/10]**
# ### **Explicación de la puntuación**:
# - **✅ Puntos fuertes**:
#   - Funciona correctamente para el caso básico.
#   - Código simple y fácil de entender.
#   - Uso de estructuras de datos adecuadas (listas y diccionarios).
#
# - **❌ Puntos débiles**:
#   - **Falta robustez**: No maneja errores ni datos inválidos.
#   - **Falta escalabilidad**: No está optimizado para grandes volúmenes.
#   - **Falta seguridad**: No valida tipos ni sanitiza datos.
#   - **Falta documentación**: No hay docstring ni comentarios.
#   - **Falta tipado**: No usa anotaciones de tipo.
#
# ### **¿Cómo mejorar la puntuación?**
# - **Añadir validación de datos** → 8/10.
# - **Usar comprensiones de listas y tipado** → 9/10.
# - **Añadir manejo de errores y logging** → 10/10.
#
# ---
#
# ### **📝 Versión Mejorada del Código**
# ```python
# from typing import List, Dict, Any
#
# def process_user_data(users: List[Dict[str, Any]]) -> List[Dict[str, str]]:
#     """
#     Filtra y transforma usuarios mayores de 18 años.
#
#     Args:
#         users: Lista de diccionarios con claves "age" (int/float), "name" (str) y "email" (str).
#
#     Returns:
#         Lista de usuarios adultos con nombre en mayúsculas y estado "adult".
#
#     Raises:
#         ValueError: Si algún usuario tiene datos inválidos.
#     """
#     if not isinstance(users, list):
#         raise TypeError("users debe ser una lista")
#
#     result = []
#     for user in users:
#         # Validación de claves
#         if not all(key in user for key in ("age", "name", "email")):
#             raise ValueError(f"Faltan claves en el usuario: {user}")
#
#         # Validación de tipos
#         if not isinstance(user["age"], (int, float)):
#             raise ValueError(f"Edad inválida para el usuario {user['name']}")
#         if not isinstance(user["name"], str):
#             raise ValueError(f"Nombre inválido para el usuario con email {user['email']}")
#         if not isinstance(user["email"], str):
#             raise ValueError(f"Email inválido para el usuario {user['name']}")
#
#         # Lógica principal
#         if user["age"] > 18:
#             result.append({
#                 "name": user["name"].upper(),
#                 "email": user["email"],
#                 "status": "adult"
#             })
#
#     return result
# ```
#
# ### **📌 Conclusión**
# El código original es funcional pero **poco robusto y no escalable**. Con las mejoras sugeridas, se convierte en una solución más segura, eficiente y mantenible, acercándose a un **10/10** en calidad.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")
    
    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.
    
    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'
        
    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users
    
    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''
    
    prompt_tests = f"""Eres un QA engineer experto en testing de Python.
    
Genera tests unitarios completos para la siguiente función usando pytest.
    
Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado
    
Función a testear:
```python
{funcion_a_testear}
```
    
Genera código de test completo y ejecutable:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)
        
        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")
        
        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# # Tests Unitarios para `calculate_discount` con pytest
#
# Aquí tienes un conjunto completo de tests unitarios para la función `calculate_discount` usando pytest, cubriendo todos los casos solicitados:
#
# ```python
# import pytest
# from your_module import calculate_discount  # Reemplaza 'your_module' con el nombre real de tu módulo
#
# class TestCalculateDiscount:
#     """Test suite for calculate_discount function."""
#
#     # ======================
#     # Casos normales
#     # ======================
#
#     def test_regular_user_standard_discount(self):
#         """Test regular user with standard discount."""
#         assert calculate_discount(100.0, 10.0, 'regular') == 90.0
#
#     def test_premium_user_standard_discount(self):
#         """Test premium user with standard discount (5% extra)."""
#         assert calculate_discount(100.0, 10.0, 'premium') == 85.0
#
#     def test_regular_user_high_discount(self):
#         """Test regular user with high discount."""
#         assert calculate_discount(200.0, 50.0, 'regular') == 100.0
#
#     def test_premium_user_high_discount(self):
#         """Test premium user with high discount (5% extra)."""
#         assert calculate_discount(200.0, 50.0, 'premium') == 90.0
#
#     def test_regular_user_no_discount(self):
#         """Test regular user with no discount."""
#         assert calculate_discount(150.0, 0.0, 'regular') == 150.0
#
#     def test_premium_user_no_discount(self):
#         """Test premium user with no discount (gets 5% extra)."""
#         assert calculate_discount(150.0, 0.0, 'premium') == 142.5
#
#     # ======================
#     # Casos edge
#     # ======================
#
#     def test_discount_100_percent_regular(self):
#         """Test regular user with 100% discount."""
#         assert calculate_discount(50.0, 100.0, 'regular') == 0.0
#
#     def test_discount_100_percent_premium(self):
#         """Test premium user with 100% discount (5% extra makes it 105%)."""
#         assert calculate_discount(50.0, 100.0, 'premium') == 0.0  # 105% discount means price becomes negative, but we return 0
#
#     def test_negative_price(self):
#         """Test with negative price (edge case)."""
#         # Nota: La función no valida precios negativos, así que esperamos un comportamiento específico
#         assert calculate_discount(-100.0, 10.0, 'regular') == -90.0
#
#     def test_negative_discount_percent(self):
#         """Test with negative discount percent (edge case)."""
#         # Esto aumentaría el precio en lugar de disminuirlo
#         assert calculate_discount(100.0, -10.0, 'regular') == 110.0
#
#     # ======================
#     # Casos de error
#     # ======================
#
#     def test_invalid_user_type(self):
#         """Test with invalid user type."""
#         with pytest.raises(ValueError):
#             calculate_discount(100.0, 10.0, 'invalid_user')
#
#     def test_string_price(self):
#         """Test with string price (should raise TypeError)."""
#         with pytest.raises(TypeError):
#             calculate_discount("100.0", 10.0, 'regular')
#
#     def test_string_discount_percent(self):
#         """Test with string discount percent (should raise TypeError)."""
#         with pytest.raises(TypeError):
#             calculate_discount(100.0, "10.0", 'regular')
#
#     def test_none_price(self):
#         """Test with None price (should raise TypeError)."""
#         with pytest.raises(TypeError):
#             calculate_discount(None, 10.0, 'regular')
#
#     # ======================
#     # Tests parametrizados
#     # ======================
#
#     @pytest.mark.parametrize("price, discount_percent, user_type, expected", [
#         (100.0, 0.0, 'regular', 100.0),
#         (100.0, 0.0, 'premium', 95.0),
#         (100.0, 100.0, 'regular', 0.0),
#         (100.0, 100.0, 'premium', -5.0),  # 105% discount
#         (0.0, 50.0, 'regular', 0.0),
#         (250.50, 25.5, 'premium', 178.1625),  # 25.5 + 5 = 30.5% discount
#     ])
#     def test_parametrized_discount_calculations(self, price, discount_percent, user_type, expected):
#         """Parametrized test for various discount scenarios."""
#         assert calculate_discount(price, discount_percent, user_type) == expected
#
#     @pytest.mark.parametrize("invalid_price", [
#         "100.0",
#         None,
#         [100.0],
#         {"price": 100.0},
#     ])
#     def test_invalid_price_types(self, invalid_price):
#         """Test that invalid price types raise TypeError."""
#         with pytest.raises(TypeError):
#             calculate_discount(invalid_price, 10.0, 'regular')
#
#     @pytest.mark.parametrize("invalid_discount_percent", [
#         "10.0",
#         None,
#         [10.0],
#         {"discount": 10.0},
#     ])
#     def test_invalid_discount_percent_types(self, invalid_discount_percent):
#         """Test that invalid discount percent types raise TypeError."""
#         with pytest.raises(TypeError):
#             calculate_discount(100.0, invalid_discount_percent, 'regular')
#
#     @pytest.mark.parametrize("invalid_user_type", [
#         123,
#         None,
#         [1, 2, 3],
#         {"user": "premium"},
#         "",
#     ])
#     def test_invalid_user_type_types(self, invalid_user_type):
#         """Test that invalid user type types raise TypeError or ValueError."""
#         with pytest.raises((TypeError, ValueError)):
#             calculate_discount(100.0, 10.0, invalid_user_type)
# ```
#
# ## Notas importantes:
#
# 1. **Módulo**: Asegúrate de reemplazar `your_module` con el nombre real de tu módulo Python donde está definida la función.
#
# 2. **Validación de tipos**: La función original no valida los tipos de entrada, pero los tests asumen que debería hacerlo (por eso los tests de error verifican que se lancen excepciones). Si la función no debe validar, deberías ajustar los tests.
#
# 3. **Comportamiento con valores negativos**: La función no valida precios negativos ni descuentos negativos, así que los tests reflejan ese comportamiento.
#
# 4. **Descuento del 105%**: Para el caso de premium con 100% de descuento, el descuento se convierte en 105%, lo que haría que el precio final sea negativo. Los tests reflejan este comportamiento.
#
# 5. **Precision en floats**: Los tests usan aproximaciones (como `== 0.0` para precios finales). En un entorno real, podrías necesitar usar `pytest.approx` para comparaciones de floats.
#
# ## Recomendaciones adicionales:
#
# 1. Si quieres que la función valide mejor los inputs, podrías modificarla así:
#
# ```python
# def calculate_discount(price, discount_percent, user_type):
#     """Calculate final price after discount.
#
#     Args:
#         price (float): Original price (must be >= 0)
#         discount_percent (float): Discount percentage (0-100)
#         user_type (str): 'premium' or 'regular'
#
#     Returns:
#         float: Final price after discount
#
#     Raises:
#         ValueError: If price is negative or discount_percent is outside 0-100
#         TypeError: If any parameter has invalid type
#     """
#     if not isinstance(price, (int, float)):
#         raise TypeError("Price must be a number")
#     if not isinstance(discount_percent, (int, float)):
#         raise TypeError("Discount percent must be a number")
#     if not isinstance(user_type, str):
#         raise TypeError("User type must be a string")
#     if user_type not in ('premium', 'regular'):
#         raise ValueError("User type must be 'premium' or 'regular'")
#     if price < 0:
#         raise ValueError("Price cannot be negative")
#     if not 0 <= discount_percent <= 100:
#         raise ValueError("Discount percent must be between 0 and 100")
#
#     if user_type == 'premium':
#         discount_percent += 5  # Extra 5% for premium users
#
#     discount_amount = price * (discount_percent / 100)
#     final_price = price - discount_amount
#
#     return max(0.0, final_price)  # Asegurar que no devuelva precios negativos
# ```
#
# Con esta versión mejorada de la función, los tests de error serían más consistentes.
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 18
# • Assertions: 11
# • Tests parametrizados: 4
# • Cobertura estimada: Alta

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")
    
    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ
    
# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""
    
    print(prompt_estudiante)
    
    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
    
Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
    
Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción
    
Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior
    
Descripción de trabajo:"""
    
    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)
    
    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario
    
ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
