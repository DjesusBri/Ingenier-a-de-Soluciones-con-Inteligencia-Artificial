# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/Mistral/RA1/IL1.2/4-advanced-techniques.ipynb)

# %% [markdown]
# # 4. Técnicas Avanzadas de Prompting
#
# ## Objetivos de Aprendizaje
# - Implementar Tree of Thoughts (ToT) para exploración de soluciones
# - Aplicar Self-Consistency para mejorar confiabilidad
# - Usar Program-Aided Language Models para cálculos precisos
# - Dominar Meta-Prompting y Prompt Chaining
#
# ## Introducción a Técnicas Avanzadas
#
# Las técnicas avanzadas de prompting van más allá de los enfoques básicos (zero-shot, few-shot, CoT) para abordar problemas complejos que requieren:
# - **Exploración de múltiples caminos** de solución
# - **Verificación y consistencia** en las respuestas
# - **Integración con herramientas** externas
# - **Composición de prompts** para tareas complejas
#
# ### Técnicas que Exploraremos:
# 1. **Tree of Thoughts (ToT)**: Exploración sistemática de alternativas
# 2. **Self-Consistency**: Múltiples caminos hacia la misma respuesta
# 3. **Program-Aided Language Models**: LLMs + código ejecutable
# 4. **Meta-Prompting**: Prompts que generan prompts
# 5. **Prompt Chaining**: Secuencias de prompts coordinados

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.mistral.ai/v1")
    os.environ.setdefault("LLM_MODEL", "mistral-small-latest")
    os.environ.setdefault("LLM_MODEL_SMALL", "ministral-8b-latest")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage
import os
import json
import re
from collections import Counter

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
    temperature=0.7  # Balance para exploración y consistencia
)

print("✓ Modelo configurado para técnicas avanzadas")
print("✓ Temperature balanceada para exploración creativa")
# Out:
# ✓ Modelo configurado para técnicas avanzadas
# ✓ Temperature balanceada para exploración creativa

# %% [markdown]
# ## 1. Tree of Thoughts (ToT)
#
# Tree of Thoughts permite al modelo explorar múltiples caminos de razonamiento de manera sistemática, evaluando y seleccionando las mejores opciones.

# %%
# Implementación de Tree of Thoughts
def tree_of_thoughts_ejemplo():
    print("=== TREE OF THOUGHTS (ToT) ===")
    
    # Problema complejo que requiere exploración de alternativas
    problema = """Una startup de foodtech necesita lanzar su app en 3 meses con un presupuesto de 50,000€. 
    Debe decidir entre tres estrategias de desarrollo:
    1. Desarrollo nativo (iOS/Android por separado)
    2. Desarrollo híbrido (React Native/Flutter)
    3. PWA (Progressive Web App)
    
    Factores a considerar: tiempo, costo, rendimiento, experiencia de usuario, escalabilidad futura."""
    
    # Prompt ToT estructurado
    prompt_tot = f"""Usa Tree of Thoughts para resolver este problema de decisión:
    
{problema}
    
PASO 1 - GENERAR RAMAS DE PENSAMIENTO:
Para cada opción (Nativa, Híbrida, PWA), desarrolla un análisis inicial considerando:
- Viabilidad técnica en 3 meses
- Ajuste al presupuesto
- Pros y contras principales
    
PASO 2 - EVALUAR CADA RAMA:
Puntúa cada opción (1-10) en:
- Tiempo de desarrollo
- Costo total
- Calidad UX
- Escalabilidad
- Riesgo técnico
    
PASO 3 - EXPLORAR SUB-RAMAS:
Para las 2 mejores opciones, explora variantes:
- Diferentes frameworks/herramientas
- Estrategias de implementación por fases
- Opciones de tercerización vs. equipo interno
    
PASO 4 - SÍNTESIS Y DECISIÓN:
Basándote en toda la exploración, recomienda la mejor estrategia con plan de implementación.
    
Análisis Tree of Thoughts:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_tot)])
        print("PROBLEMA DE DECISIÓN:")
        print(problema)
        print("\nANÁLISIS TREE OF THOUGHTS:")
        print(response.content)
        
        # Analizar la estructura del ToT
        contenido = response.content.lower()
        pasos_presentes = sum(1 for i in range(1, 5) if f'paso {i}' in contenido)
        opciones_evaluadas = sum(1 for opt in ['nativa', 'híbrida', 'pwa'] if opt in contenido)
        tiene_puntuacion = any(str(i) in contenido for i in range(1, 11))
        
        print(f"\n=== ANÁLISIS DE LA ESTRUCTURA ToT ===")
        print(f"✓ Pasos desarrollados: {pasos_presentes}/4")
        print(f"✓ Opciones evaluadas: {opciones_evaluadas}/3")
        print(f"✓ Incluye puntuaciones: {'Sí' if tiene_puntuacion else 'No'}")
        print(f"✓ Estructura completa: {'Sí' if pasos_presentes >= 3 and opciones_evaluadas >= 2 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar Tree of Thoughts
tree_of_thoughts_ejemplo()
# Out:
# === TREE OF THOUGHTS (ToT) ===
# PROBLEMA DE DECISIÓN:
# Una startup de foodtech necesita lanzar su app en 3 meses con un presupuesto de 50,000€.
#     Debe decidir entre tres estrategias de desarrollo:
#     1. Desarrollo nativo (iOS/Android por separado)
#     2. Desarrollo híbrido (React Native/Flutter)
#     3. PWA (Progressive Web App)
#
#     Factores a considerar: tiempo, costo, rendimiento, experiencia de usuario, escalabilidad futura.
#
# ANÁLISIS TREE OF THOUGHTS:
# ### **Tree of Thoughts: Decisión Estratégica para el Lanzamiento de la App**
#
# **Contexto:**
# Startup de foodtech con **3 meses** de plazo y **50,000€** para lanzar una app móvil. Debe elegir entre:
# 1. **Desarrollo nativo** (iOS/Android por separado)
# 2. **Desarrollo híbrido** (React Native/Flutter)
# 3. **PWA** (Progressive Web App)
#
# **Factores clave:**
# ✅ **Tiempo** (3 meses)
# ✅ **Costo** (≤50,000€)
# ✅ **Rendimiento**
# ✅ **Experiencia de usuario (UX)**
# ✅ **Escalabilidad futura**
#
# ---
#
# ## **PASO 1 - GENERAR RAMAS DE PENSAMIENTO**
#
# ### **Opción 1: Desarrollo Nativo (iOS/Android)**
# **Análisis inicial:**
# - **Tiempo:**
#   - 2-3 meses en desarrollo (si hay equipo experimentado).
#   - Requiere desarrollo paralelo para ambas plataformas (costos adicionales).
# - **Costo:**
#   - Salarios de desarrolladores especializados (iOS/Android) = **~30,000-40,000€**.
#   - Mantenimiento futuro más caro (dos codebases).
# - **Pros:**
#   - **Mejor rendimiento** (velocidad, animaciones, acceso a APIs nativas).
#   - **Experiencia de usuario superior** (navegación fluida, integración con hardware).
#   - **Escalabilidad a largo plazo** (fácil de mantener y actualizar).
# - **Contras:**
#   - **Tiempo de desarrollo más lento** (dos equipos o uno trabajando en paralelo).
#   - **Costos iniciales altos** (equipo especializado).
#   - **Dependencia de tiendas de apps** (Apple Store/Google Play).
#
# **Viabilidad en 3 meses:**
# ⚠️ **Riesgo moderado** (requiere equipo senior y buena planificación).
# 💰 **Presupuesto ajustado** (podría superar 50,000€ si hay imprevistos).
#
# ---
#
# ### **Opción 2: Desarrollo Híbrido (React Native o Flutter)**
# **Análisis inicial:**
# - **Tiempo:**
#   - 1.5-2.5 meses (solo una codebase para ambas plataformas).
#   - Más rápido que nativo, pero depende de la complejidad.
# - **Costo:**
#   - Salarios de desarrolladores full-stack = **~20,000-30,000€**.
#   - Menos costos de mantenimiento (misma base de código).
# - **Pros:**
#   - **Desarrollo más rápido** (solo una versión).
#   - **Costos reducidos** (menos personal especializado).
#   - **Experiencia de usuario aceptable** (casi indistinguible de nativo para muchas apps).
#   - **Escalabilidad** (fácil de actualizar y mantener).
# - **Contras:**
#   - **Rendimiento inferior** (puede haber latencias en animaciones complejas).
#   - **Dependencia de frameworks** (React Native/Flutter pueden cambiar).
#   - **Acceso limitado a APIs nativas** (aunque se pueden puentea).
#
# **Viabilidad en 3 meses:**
# ✅ **Alta probabilidad** (desarrollo rápido y eficiente).
# 💰 **Dentro del presupuesto** (con optimización de recursos).
#
# **Frameworks candidatos:**
# - **React Native** (más maduro, gran comunidad, pero JavaScript).
# - **Flutter** (Dart, mejor rendimiento, pero comunidad más pequeña).
#
# ---
#
# ### **Opción 3: PWA (Progressive Web App)**
# **Análisis inicial:**
# - **Tiempo:**
#   - 1-2 meses (desarrollo web con funcionalidad offline).
#   - No requiere publicación en tiendas (pero puede usar "Installable Web Apps").
# - **Costo:**
#   - Salarios de desarrolladores web = **~15,000-25,000€**.
#   - Hosting y dominios (~1,000-2,000€/año).
# - **Pros:**
#   - **Más barato y rápido** (solo un desarrollo).
#   - **Sin dependencia de tiendas** (acceso directo via URL).
#   - **Actualizaciones instantáneas** (sin aprobación de Apple/Google).
#   - **Funciona en cualquier dispositivo** (incluso en navegadores antiguos).
# - **Contras:**
#   - **Experiencia de usuario limitada** (menos integrada con el sistema).
#   - **Rendimiento inferior** (depende del navegador).
#   - **Almacenamiento offline no garantizado** (depende del usuario).
#   - **Menor engagement** (menos visible en tiendas de apps).
#
# **Viabilidad en 3 meses:**
# ✅ **Muy alta** (desarrollo web es más rápido).
# 💰 **Dentro del presupuesto** (costo mínimo).
#
# ---
#
# ## **PASO 2 - EVALUAR CADA RAMA (Puntuación 1-10)**
#
# | **Criterio**       | **Nativo** | **Híbrido** | **PWA** |
# |---------------------|-----------|-------------|---------|
# | **Tiempo de desarrollo** | 6        | 9           | 10      |
# | **Costo total**     | 4         | 8           | 10      |
# | **Calidad UX**      | 10        | 8           | 6       |
# | **Escalabilidad**   | 10        | 9           | 7       |
# | **Riesgo técnico**  | 5         | 7           | 9       |
# | **Total**           | **35**    | **41**      | **42**  |
#
# **Análisis:**
# - **PWA** lidera en **tiempo y costo**, pero **pierde en UX y escalabilidad**.
# - **Híbrido** tiene un **buen equilibrio** (9 en tiempo/costo, 8 en UX).
# - **Nativo** es el mejor en **UX y escalabilidad**, pero **caro y lento**.
#
# **Conclusión inicial:**
# ✅ **PWA y Híbrido** son las mejores opciones.
# ❌ **Nativo** queda descartado por costos y tiempo.
#
# ---
#
# ## **PASO 3 - EXPLORAR SUB-RAMAS (Variantes para las 2 mejores opciones)**
#
# ### **Sub-Ramas para Híbrido (React Native vs. Flutter)**
# | **Criterio**       | **React Native** | **Flutter** |
# |---------------------|------------------|-------------|
# | **Rendimiento**     | 7                | 9           |
# | **Comunidad**       | 10               | 7           |
# | **Curva de aprendizaje** | 8           | 6           |
# | **Costos**          | 8                | 7           |
# | **Total**           | **33**           | **29**      |
#
# **Recomendación:**
# - **React Native** es mejor por **comunidad y costos**.
# - **Flutter** podría usarse si el equipo ya lo domina o si se necesita **alto rendimiento**.
#
# **Estrategia de implementación híbrida:**
# 1. **Fase 1 (1 mes):** MVP con React Native (solo funciones clave).
# 2. **Fase 2 (1 mes):** Integración de APIs de pago/mapa.
# 3. **Fase 3 (1 mes):** Testing, correcciones y lanzamiento.
#
# ---
#
# ### **Sub-Ramas para PWA (Frameworks y Enfoques)**
# | **Criterio**       | **Next.js + PWA** | **Vue.js + PWA** | **Angular PWA** |
# |---------------------|-------------------|------------------|-----------------|
# | **Rendimiento**     | 8                 | 7                | 9               |
# | **Facilidad**       | 9                 | 8                | 6               |
# | **SEO**            | 10                | 8                | 7               |
# | **Costos**          | 9                 | 8                | 7               |
# | **Total**           | **36**            | **31**           | **29**          |
#
# **Recomendación:**
# - **Next.js + PWA** es la mejor opción por **rendimiento y SEO**.
# - **Vue.js** es buena alternativa si el equipo ya lo usa.
#
# **Estrategia de implementación PWA:**
# 1. **Fase 1 (2 semanas):** Diseño y prototipo en Figma.
# 2. **Fase 2 (3 semanas):** Desarrollo con Next.js y Service Workers.
# 3. **Fase 3 (1 semana):** Testing en dispositivos reales.
#
# ---
#
# ## **PASO 4 - SÍNTESIS Y DECISIÓN FINAL**
#
# ### **Comparación Final:**
# | **Criterio**       | **Híbrido (React Native)** | **PWA (Next.js)** |
# |---------------------|---------------------------|-------------------|
# | **Tiempo**          | 9                         | 10                |
# | **Costo**           | 8                         | 10                |
# | **Rendimiento**     | 8                         | 7                 |
# | **UX**             | 9                         | 7                 |
# | **Escalabilidad**   | 9                         | 8                 |
# | **Riesgo técnico**  | 7                         | 9                 |
# | **Total**           | **41**                    | **41**            |
#
# **Decisión:**
# ✅ **Empate técnico entre Híbrido y PWA**, pero con enfoques distintos:
# - **Si la prioridad es el lanzamiento rápido y bajo costo → PWA.**
# - **Si se necesita mejor UX y escalabilidad a largo plazo → Híbrido.**
#
# **Recomendación final:**
# 🔹 **Elegir PWA (Next.js) si:**
# - El MVP es simple (catálogo, pedidos básicos).
# - No se necesita acceso a APIs nativas complejas.
# - Se quiere lanzar **en 2 meses** con **≤30,000€**.
#
# 🔹 **Elegir Híbrido (React Native) si:**
# - La app requiere **buena experiencia de usuario** (animaciones, navegación).
# - Se planea **escalar a largo plazo** (más funcionalidades).
# - Se tiene un equipo con experiencia en React.
#
# **Plan de Implementación Recomendado (Híbrido - React Native):**
# 1. **Mes 1:**
#    - Contratar 2 desarrolladores React Native (frontend + backend).
#    - Diseñar wireframes y prototipo en Figma.
#    - Desarrollar MVP básico (login, catálogo, carrito).
# 2. **Mes 2:**
#    - Integrar APIs de pago y geolocalización.
#    - Testing en iOS/Android (emuladores y dispositivos reales).
# 3. **Mes 3:**
#    - Correcciones de bugs.
#    - Publicación en App Store y Play Store.
#    - Marketing y feedback inicial.
#
# **Presupuesto estimado:**
# - Desarrollo: **30,000-35,000€**
# - Hosting y dominios: **2,000€**
# - Marketing inicial: **5,000€**
# - Imprevistos: **3,000€**
# ✅ **Total: ~45,000€ (dentro del presupuesto).**
#
# ---
#
# ### **Conclusión:**
# **La mejor opción es el desarrollo híbrido con React Native**, ya que ofrece un **buen equilibrio entre tiempo, costo y calidad**, permitiendo escalar en el futuro. Si el tiempo fuera crítico y la app fuera muy simple, **la PWA sería la elección**, pero con posibles limitaciones en UX.
#
# **✅ **Recomendación final: React Native (Híbrido).**
#
# === ANÁLISIS DE LA ESTRUCTURA ToT ===
# ✓ Pasos desarrollados: 4/4
# ✓ Opciones evaluadas: 3/3
# ✓ Incluye puntuaciones: Sí
# ✓ Estructura completa: Sí

# %% [markdown]
# ## 2. Self-Consistency
#
# Self-Consistency mejora la confiabilidad generando múltiples respuestas y seleccionando la más consistente.

# %%
# Implementación de Self-Consistency
def self_consistency_ejemplo():
    print("=== SELF-CONSISTENCY ===")
    
    # Problema con múltiples caminos de solución
    problema = """Una empresa de logística necesita optimizar la distribución de 1000 paquetes 
    entre 5 centros de distribución. Los centros tienen capacidades de 150, 200, 250, 200, 200 paquetes respectivamente.
    Los costos de envío por paquete son: Centro A: 2€, Centro B: 1.5€, Centro C: 3€, Centro D: 2.5€, Centro E: 1.8€.
    ¿Cuál es la distribución óptima que minimiza costos?"""
    
    # Generar múltiples respuestas con diferentes enfoques
    enfoques = [
        "Resuelve este problema de optimización priorizando el menor costo por paquete:",
        "Resuelve este problema usando un enfoque de programación lineal simple:",
        "Resuelve este problema considerando tanto costo como capacidad balanceadamente:",
        "Resuelve este problema paso a paso ordenando centros por eficiencia costo-capacidad:"
    ]
    
    respuestas = []
    distribuciones = []
    
    print("PROBLEMA DE OPTIMIZACIÓN:")
    print(problema)
    print("\n=== GENERANDO MÚLTIPLES SOLUCIONES ===")
    
    for i, enfoque in enumerate(enfoques, 1):
        prompt = f"{enfoque}\n\n{problema}\n\nProporciona la distribución específica (número de paquetes por centro) y el costo total."
        
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            respuestas.append(response.content)
            
            print(f"\nENFOQUE {i}:")
            print(f"Método: {enfoque}")
            print(f"Respuesta: {response.content[:200]}...")
            
            # Extraer números de la respuesta (distribución)
            numeros = re.findall(r'\d+', response.content)
            if len(numeros) >= 5:
                distribucion = [int(x) for x in numeros[:5] if int(x) <= 250]  # Filtrar números razonables
                if len(distribucion) == 5 and sum(distribucion) <= 1100:  # Validación básica
                    distribuciones.append(distribucion)
                    print(f"Distribución extraída: {distribucion}")
            
        except Exception as e:
            print(f"Error en enfoque {i}: {e}")
    
    # Análisis de consistencia
    print(f"\n=== ANÁLISIS DE CONSISTENCIA ===")
    print(f"✓ Respuestas generadas: {len(respuestas)}/4")
    print(f"✓ Distribuciones válidas: {len(distribuciones)}")
    
    if len(distribuciones) >= 2:
        # Calcular distribución promedio
        distribucion_promedio = []
        for i in range(5):
            promedio = sum(dist[i] for dist in distribuciones if i < len(dist)) / len(distribuciones)
            distribucion_promedio.append(round(promedio))
        
        print(f"✓ Distribución consensus: {distribucion_promedio}")
        
        # Verificar consistencia
        variaciones = []
        for i in range(5):
            valores = [dist[i] for dist in distribuciones if i < len(dist)]
            if valores:
                variacion = max(valores) - min(valores)
                variaciones.append(variacion)
        
        variacion_promedio = sum(variaciones) / len(variaciones) if variaciones else 0
        print(f"✓ Variación promedio: {variacion_promedio:.1f} paquetes")
        print(f"✓ Consistencia: {'Alta' if variacion_promedio < 50 else 'Media' if variacion_promedio < 100 else 'Baja'}")
    
    else:
        print("✗ Insuficientes distribuciones válidas para análisis de consistencia")

# Ejecutar Self-Consistency
self_consistency_ejemplo()
# Out:
# === SELF-CONSISTENCY ===
# PROBLEMA DE OPTIMIZACIÓN:
# Una empresa de logística necesita optimizar la distribución de 1000 paquetes
#     entre 5 centros de distribución. Los centros tienen capacidades de 150, 200, 250, 200, 200 paquetes respectivamente.
#     Los costos de envío por paquete son: Centro A: 2€, Centro B: 1.5€, Centro C: 3€, Centro D: 2.5€, Centro E: 1.8€.
#     ¿Cuál es la distribución óptima que minimiza costos?
#
# === GENERANDO MÚLTIPLES SOLUCIONES ===
# ENFOQUE 1:
# Método: Resuelve este problema de optimización priorizando el menor costo por paquete:
# Respuesta: Para resolver este problema de optimización con el objetivo de minimizar el costo total de envío, seguiremos estos pasos:
#
# ### **1. Datos del problema:**
# - **Paquetes totales a distribuir:** 1000
# - **...
# ENFOQUE 2:
# Método: Resuelve este problema usando un enfoque de programación lineal simple:
# Respuesta: Para resolver este problema de optimización de distribución de paquetes entre los centros, podemos plantearlo como un **problema de programación lineal** donde el objetivo es **minimizar el costo tota...
# ENFOQUE 3:
# Método: Resuelve este problema considerando tanto costo como capacidad balanceadamente:
# Respuesta: Para resolver este problema de optimización, utilizaremos un enfoque balanceado que minimice el costo total de envío mientras respetamos las capacidades de cada centro de distribución. Este es un prob...
# ENFOQUE 4:
# Método: Resuelve este problema paso a paso ordenando centros por eficiencia costo-capacidad:
# Respuesta: Para resolver este problema de optimización logística, seguiremos un enfoque **greedy** (voraz), priorizando los centros con la mejor relación **eficiencia costo-capacidad** (es decir, menor costo por...
# Distribución extraída: [1, 150, 2, 2, 150]
#
# === ANÁLISIS DE CONSISTENCIA ===
# ✓ Respuestas generadas: 4/4
# ✓ Distribuciones válidas: 1
# ✗ Insuficientes distribuciones válidas para análisis de consistencia

# %% [markdown]
# ## 3. Program-Aided Language Models (PAL)
#
# PAL combina el razonamiento de LLMs con la precisión de código ejecutable para cálculos exactos.

# %%
# Implementación de Program-Aided Language Models
def program_aided_language_model():
    print("=== PROGRAM-AIDED LANGUAGE MODEL (PAL) ===")
    
    # Problema que requiere cálculos precisos
    problema = """Una empresa de suscripciones tiene los siguientes datos mensuales:
    - Usuarios nuevos: 1,250
    - Tasa de conversión a premium: 12.5%
    - Precio premium: 29.99€/mes
    - Churn rate mensual: 8.3%
    - Usuarios premium actuales: 15,420
    - Costo de adquisición por usuario: 18.50€
    
    Calcula: MRR (Monthly Recurring Revenue), crecimiento neto de usuarios premium, 
    y proyección de MRR para los próximos 6 meses."""
    
    # Prompt PAL que genera código ejecutable
    prompt_pal = f"""Resuelve este problema generando código Python ejecutable:
    
{problema}
    
Estructura tu respuesta así:
    
ANÁLISIS:
Explica el problema y los cálculos necesarios.
    
CÓDIGO:
```python
# Código Python para resolver el problema
# Incluye comentarios explicativos
# Define variables claramente
# Realiza cálculos paso a paso
# Muestra resultados formatados
```
    
INTERPRETACIÓN:
Explica los resultados y su significado para el negocio.
    
Solución PAL:"""
    
    try:
        response = llm.invoke([HumanMessage(content=prompt_pal)])
        print("PROBLEMA DE CÁLCULO FINANCIERO:")
        print(problema)
        print("\nSOLUCIÓN PAL:")
        print(response.content)
        
        # Extraer y ejecutar código Python si es posible
        codigo_match = re.search(r'```python\n(.*?)\n```', response.content, re.DOTALL)
        if codigo_match:
            codigo = codigo_match.group(1)
            print("\n=== CÓDIGO EXTRAÍDO ===")
            print(codigo)
            
            # Intentar ejecutar (solo con operaciones seguras)
            if all(palabra not in codigo.lower() for palabra in ['import', 'exec', 'eval', 'open', 'file']):
                try:
                    print("\n=== EJECUCIÓN DEL CÓDIGO ===")
                    # Crear un namespace seguro
                    namespace = {}
                    exec(codigo, {"__builtins__": {"print": print, "round": round}}, namespace)
                    print("✓ Código ejecutado exitosamente")
                except Exception as e:
                    print(f"✗ Error en ejecución: {e}")
            else:
                print("⚠️ Código contiene imports - no ejecutado por seguridad")
        else:
            print("✗ No se encontró código Python en la respuesta")
        
        # Análisis de la estructura PAL
        contenido = response.content.lower()
        tiene_analisis = 'análisis' in contenido or 'problema' in contenido
        tiene_codigo = '```python' in response.content
        tiene_interpretacion = 'interpretación' in contenido or 'resultado' in contenido
        tiene_comentarios = '#' in response.content
        
        print(f"\n=== ANÁLISIS DE LA ESTRUCTURA PAL ===")
        print(f"✓ Incluye análisis: {'Sí' if tiene_analisis else 'No'}")
        print(f"✓ Incluye código: {'Sí' if tiene_codigo else 'No'}")
        print(f"✓ Incluye interpretación: {'Sí' if tiene_interpretacion else 'No'}")
        print(f"✓ Código comentado: {'Sí' if tiene_comentarios else 'No'}")
        
        estructura_completa = sum([tiene_analisis, tiene_codigo, tiene_interpretacion, tiene_comentarios])
        print(f"✓ Estructura PAL: {'Completa' if estructura_completa >= 3 else 'Parcial'}")
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar Program-Aided Language Model
program_aided_language_model()
# Out:
# === PROGRAM-AIDED LANGUAGE MODEL (PAL) ===
# PROBLEMA DE CÁLCULO FINANCIERO:
# Una empresa de suscripciones tiene los siguientes datos mensuales:
#     - Usuarios nuevos: 1,250
#     - Tasa de conversión a premium: 12.5%
#     - Precio premium: 29.99€/mes
#     - Churn rate mensual: 8.3%
#     - Usuarios premium actuales: 15,420
#     - Costo de adquisición por usuario: 18.50€
#
#     Calcula: MRR (Monthly Recurring Revenue), crecimiento neto de usuarios premium,
#     y proyección de MRR para los próximos 6 meses.
#
# SOLUCIÓN PAL:
# # Análisis
#
# **Problema:**
# La empresa necesita calcular métricas clave de su negocio de suscripciones:
# 1. **MRR (Monthly Recurring Revenue):** Ingresos recurrentes mensuales de los usuarios premium.
# 2. **Crecimiento neto de usuarios premium:** Diferencia entre usuarios nuevos premium y usuarios perdidos (churn).
# 3. **Proyección de MRR para 6 meses:** Estimación de los ingresos futuros considerando crecimiento y churn.
#
# **Cálculos necesarios:**
# 1. **MRR actual:** Usuarios premium actuales × Precio premium
# 2. **Nuevos usuarios premium:** Usuarios nuevos × Tasa de conversión (en decimal)
# 3. **Pérdidas por churn:** Usuarios premium actuales × Churn rate (en decimal)
# 4. **Crecimiento neto:** Nuevos usuarios premium - Pérdidas por churn
# 5. **Nuevos usuarios premium totales:** Usuarios premium actuales + Crecimiento neto
# 6. **Proyección MRR:** Para cada mes considerar:
#    - Nuevos usuarios premium (1250 × 12.5%)
#    - Pérdidas por churn (usuarios actuales × 8.3%)
#    - MRR mensual = (Usuarios premium actuales × Precio) + (Nuevos premium × Precio)
#
# ---
#
# # Código
#
# ```python
# # Datos iniciales
# usuarios_nuevos = 1250
# tasa_conversion = 0.125  # 12.5%
# precio_premium = 29.99   # €/mes
# churn_rate = 0.083       # 8.3%
# usuarios_premium_actuales = 15420
# costo_adquisicion = 18.50 # €
#
# # 1. Cálculo del MRR actual
# mrr_actual = usuarios_premium_actuales * precio_premium
# print(f"MRR actual: {mrr_actual:.2f} €")
#
# # 2. Cálculo de nuevos usuarios premium
# nuevos_premium = usuarios_nuevos * tasa_conversion
# print(f"Nuevos usuarios premium este mes: {nuevos_premium:.0f}")
#
# # 3. Cálculo de pérdidas por churn
# perdidas_churn = usuarios_premium_actuales * churn_rate
# print(f"Pérdidas por churn este mes: {perdidas_churn:.0f} usuarios")
#
# # 4. Crecimiento neto de usuarios premium
# crecimiento_neto = nuevos_premium - perdidas_churn
# print(f"Crecimiento neto de usuarios premium: {crecimiento_neto:.0f} usuarios")
#
# # 5. Proyección de usuarios premium para el próximo mes
# usuarios_premium_proximo_mes = usuarios_premium_actuales + crecimiento_neto
# print(f"Usuarios premium estimados para el próximo mes: {usuarios_premium_proximo_mes:.0f}")
#
# # 6. Proyección de MRR para los próximos 6 meses
# mrr_proyeccion = []
# usuarios_actuales = usuarios_premium_actuales
#
# for mes in range(1, 7):
#     # Nuevos premium este mes
#     nuevos = usuarios_nuevos * tasa_conversion
#     # Pérdidas por churn
#     perdidas = usuarios_actuales * churn_rate
#     # Crecimiento neto
#     crecimiento = nuevos - perdidas
#     # Usuarios para el próximo mes
#     usuarios_actuales += crecimiento
#     # MRR para este mes
#     mrr_mes = usuarios_actuales * precio_premium
#     mrr_proyeccion.append(mrr_mes)
#     print(f"Mes {mes}: {mrr_mes:.2f} € (Usuarios: {int(usuarios_actuales)})")
#
# # Resumen final
# print("\nResumen:")
# print(f"- MRR actual: {mrr_actual:.2f} €")
# print(f"- Crecimiento neto mensual: {crecimiento_neto:.0f} usuarios")
# print(f"- Proyección MRR en 6 meses: {mrr_proyeccion[-1]:.2f} €")
# ```
#
# ---
#
# # Interpretación
#
# **Resultados clave:**
# 1. **MRR actual (462,946.80 €):**
#    - Representa los ingresos recurrentes mensuales actuales de los 15,420 usuarios premium.
#    - Base para calcular la salud financiera del negocio.
#
# 2. **Crecimiento neto (+125 usuarios):**
#    - La empresa gana 156 nuevos premium (1,250 × 12.5%) pero pierde 31 usuarios por churn (15,420 × 8.3%).
#    - **Significado:** Aunque el crecimiento es positivo, el churn (8.3%) es significativo y debe monitorizarse.
#
# 3. **Proyección MRR (520,226.83 € en 6 meses):**
#    - Los ingresos crecerán un ~12.4% en 6 meses, impulsados por el crecimiento neto de usuarios.
#    - **Riesgo:** Si el churn aumenta o la conversión disminuye, la proyección podría no cumplirse.
#
# **Recomendaciones para el negocio:**
# - **Reducir churn:** Investigar causas de deserción (ej.: precio, experiencia del usuario) y aplicar estrategias de retención (ej.: descuentos, mejoras en producto).
# - **Optimizar conversión:** Aumentar la tasa del 12.5% con campañas de marketing más efectivas o pruebas A/B en landing pages.
# - **Análisis de costo:** El costo de adquisición (18.50€) vs. el ingreso por usuario premium (29.99€) deja un margen bruto de 11.49€. Si el churn es alto, este margen se reduce.
#
# **Conclusión:**
# El negocio está en crecimiento, pero el churn moderado (8.3%) limita su potencial. Pequeñas mejoras en retención o conversión podrían tener un impacto significativo en el MRR a largo plazo.
#
# === CÓDIGO EXTRAÍDO ===
# # Datos iniciales
# usuarios_nuevos = 1250
# tasa_conversion = 0.125  # 12.5%
# precio_premium = 29.99   # €/mes
# churn_rate = 0.083       # 8.3%
# usuarios_premium_actuales = 15420
# costo_adquisicion = 18.50 # €
#
# # 1. Cálculo del MRR actual
# mrr_actual = usuarios_premium_actuales * precio_premium
# print(f"MRR actual: {mrr_actual:.2f} €")
#
# # 2. Cálculo de nuevos usuarios premium
# nuevos_premium = usuarios_nuevos * tasa_conversion
# print(f"Nuevos usuarios premium este mes: {nuevos_premium:.0f}")
#
# # 3. Cálculo de pérdidas por churn
# perdidas_churn = usuarios_premium_actuales * churn_rate
# print(f"Pérdidas por churn este mes: {perdidas_churn:.0f} usuarios")
#
# # 4. Crecimiento neto de usuarios premium
# crecimiento_neto = nuevos_premium - perdidas_churn
# print(f"Crecimiento neto de usuarios premium: {crecimiento_neto:.0f} usuarios")
#
# # 5. Proyección de usuarios premium para el próximo mes
# usuarios_premium_proximo_mes = usuarios_premium_actuales + crecimiento_neto
# print(f"Usuarios premium estimados para el próximo mes: {usuarios_premium_proximo_mes:.0f}")
#
# # 6. Proyección de MRR para los próximos 6 meses
# mrr_proyeccion = []
# usuarios_actuales = usuarios_premium_actuales
#
# for mes in range(1, 7):
#     # Nuevos premium este mes
#     nuevos = usuarios_nuevos * tasa_conversion
#     # Pérdidas por churn
#     perdidas = usuarios_actuales * churn_rate
#     # Crecimiento neto
#     crecimiento = nuevos - perdidas
#     # Usuarios para el próximo mes
#     usuarios_actuales += crecimiento
#     # MRR para este mes
#     mrr_mes = usuarios_actuales * precio_premium
#     mrr_proyeccion.append(mrr_mes)
#     print(f"Mes {mes}: {mrr_mes:.2f} € (Usuarios: {int(usuarios_actuales)})")
#
# # Resumen final
# print("\nResumen:")
# print(f"- MRR actual: {mrr_actual:.2f} €")
# print(f"- Crecimiento neto mensual: {crecimiento_neto:.0f} usuarios")
# print(f"- Proyección MRR en 6 meses: {mrr_proyeccion[-1]:.2f} €")
#
# === EJECUCIÓN DEL CÓDIGO ===
# MRR actual: 462445.80 €
# Nuevos usuarios premium este mes: 156
# Pérdidas por churn este mes: 1280 usuarios
# Crecimiento neto de usuarios premium: -1124 usuarios
# Usuarios premium estimados para el próximo mes: 14296
# ✗ Error en ejecución: name 'range' is not defined
#
# === ANÁLISIS DE LA ESTRUCTURA PAL ===
# ✓ Incluye análisis: Sí
# ✓ Incluye código: Sí
# ✓ Incluye interpretación: Sí
# ✓ Código comentado: Sí
# ✓ Estructura PAL: Completa

# %% [markdown]
# ## 4. Meta-Prompting
#
# Meta-prompting usa el LLM para generar y optimizar prompts para tareas específicas.

# %%
# Implementación de Meta-Prompting
def meta_prompting_ejemplo():
    print("=== META-PROMPTING ===")
    
    # Tarea para la cual queremos generar un prompt óptimo
    tarea_objetivo = """Crear un sistema que analice reviews de productos en e-commerce 
    y extraiga información estructurada: sentimiento, aspectos mencionados (precio, calidad, 
    envío, servicio), puntuación de satisfacción, y recomendaciones de mejora para el vendedor."""
    
    # Meta-prompt que genera prompts optimizados
    meta_prompt = f"""Eres un experto en prompt engineering. Tu tarea es crear un prompt óptimo para la siguiente necesidad:
    
TAREA OBJETIVO:
{tarea_objetivo}
    
Diseña un prompt que sea:
1. ESPECÍFICO: Instrucciones claras y detalladas
2. ESTRUCTURADO: Formato de salida bien definido
3. ROBUSTO: Maneje diferentes tipos de reviews
4. EFICIENTE: Obtenga máxima información con mínimo contexto
    
Incluye en tu prompt:
- Rol/contexto para el modelo
- Instrucciones paso a paso
- Formato de salida (preferiblemente JSON)
- Ejemplos si son necesarios
- Manejo de casos edge
    
PROMPT OPTIMIZADO:"""
    
    try:
        response = llm.invoke([HumanMessage(content=meta_prompt)])
        prompt_generado = response.content
        
        print("TAREA PARA LA CUAL GENERAR PROMPT:")
        print(tarea_objetivo)
        print("\nPROMPT GENERADO POR META-PROMPTING:")
        print(prompt_generado)
        
        # Probar el prompt generado con un ejemplo
        review_test = """Producto llegó rápido y bien empaquetado. La calidad es buena por el precio 
        que pagué (25€), aunque esperaba que fuera un poco más resistente. El servicio al cliente 
        respondió rápido cuando tuve una duda. Lo recomendaría para uso ocasional."""
        
        print("\n=== PROBANDO EL PROMPT GENERADO ===")
        print(f"Review de prueba: {review_test}")
        
        # Combinar prompt generado con review de prueba
        prompt_completo = f"{prompt_generado}\n\nReview a analizar: \"{review_test}\""
        
        try:
            test_response = llm.invoke([HumanMessage(content=prompt_completo)])
            print("\nRESULTADO DEL ANÁLISIS:")
            print(test_response.content)
            
            # Evaluar calidad del prompt generado
            resultado = test_response.content
            
            # Verificar elementos esperados
            elementos_esperados = {
                'sentimiento': any(word in resultado.lower() for word in ['positivo', 'negativo', 'neutral', 'sentimiento']),
                'aspectos': any(word in resultado.lower() for word in ['precio', 'calidad', 'envío', 'servicio']),
                'puntuacion': any(char in resultado for char in '0123456789/'),
                'estructura': '{' in resultado and '}' in resultado,  # JSON format
                'recomendaciones': any(word in resultado.lower() for word in ['recomendación', 'mejora', 'sugerencia'])
            }
            
            elementos_presentes = sum(elementos_esperados.values())
            
            print(f"\n=== EVALUACIÓN DEL PROMPT GENERADO ===")
            for elemento, presente in elementos_esperados.items():
                print(f"✓ {elemento.capitalize()}: {'Sí' if presente else 'No'}")
            
            print(f"\n✓ Efectividad del meta-prompt: {elementos_presentes}/5 elementos")
            print(f"✓ Calidad: {'Excelente' if elementos_presentes >= 4 else 'Buena' if elementos_presentes >= 3 else 'Necesita mejoras'}")
            
        except Exception as e:
            print(f"Error probando el prompt: {e}")
        
    except Exception as e:
        print(f"Error en meta-prompting: {e}")

# Ejecutar Meta-Prompting
meta_prompting_ejemplo()
# Out:
# === META-PROMPTING ===
# TAREA PARA LA CUAL GENERAR PROMPT:
# Crear un sistema que analice reviews de productos en e-commerce
#     y extraiga información estructurada: sentimiento, aspectos mencionados (precio, calidad,
#     envío, servicio), puntuación de satisfacción, y recomendaciones de mejora para el vendedor.
#
# PROMPT GENERADO POR META-PROMPTING:
# Aquí tienes un **prompt optimizado** para analizar reviews de productos en e-commerce, diseñado para ser específico, estructurado, robusto y eficiente. Incluye rol, instrucciones detalladas, formato de salida (JSON), ejemplos y manejo de casos edge:
#
# ---
#
# ### **PROMPT: Análisis de Reviews de Productos en E-commerce**
# **Rol/Contexto:**
# Eres un **analista de datos especializado en procesamiento de lenguaje natural (NLP)** con experiencia en análisis de sentimiento y extracción de aspectos para e-commerce. Tu tarea es procesar reviews de productos en texto libre y extraer información estructurada para ayudar a vendedores a mejorar su servicio y productos.
#
# ---
#
# ### **Instrucciones Paso a Paso:**
# 1. **Analiza cada review** de manera independiente (no asumas relaciones entre reviews).
# 2. **Extrae los siguientes campos** (todos son obligatorios, usa `null` si no aplica):
#    - **`review_id`**: Identificador único de la review (ej: "R12345").
#    - **`product_id`**: ID del producto (ej: "P67890").
#    - **`sentiment`**: Sentimiento general de la review en escala numérica:
#      - `1` = Muy negativo
#      - `2` = Negativo
#      - `3` = Neutral
#      - `4` = Positivo
#      - `5` = Muy positivo
#    - **`aspects_mentioned`**: Lista de aspectos mencionados en la review (máximo 5 por review). Cada aspecto debe incluir:
#      - `aspect`: Nombre del aspecto (ej: "precio", "calidad", "envío", "servicio", "diseño").
#      - `sentiment`: Sentimiento específico para ese aspecto (misma escala `1-5`).
#      - `text_evidence`: Fragmento del texto que menciona el aspecto (ej: "El precio es muy alto").
#      - `is_improvement` (boolean): `true` si la review sugiere una mejora para ese aspecto.
#    - **`satisfaction_score`**: Puntuación numérica global de satisfacción (1-10).
#    - **`recommendations`**: Lista de recomendaciones de mejora para el vendedor (máximo 3 por review). Cada recomendación debe incluir:
#      - `issue`: Problema identificado (ej: "Aumentar stock de productos").
#      - `aspect_related`: Aspecto relacionado (ej: "envío").
#      - `priority`: Prioridad (`alta`, `media`, `baja`).
#      - `quote`: Fragmento del texto que justifica la recomendación.
#    - **`metadata`**: Campo para información adicional:
#      - `language`: Idioma de la review (ej: "es").
#      - `review_length`: Longitud de la review en palabras.
#
# 3. **Manejo de Casos Edge:**
#    - **Reviews muy cortas** (ej: "Genial"): Asume sentimiento positivo (`5`) y aspectos genéricos (ej: "calidad").
#    - **Reviews en otros idiomas**: Usa `null` para campos no traducibles y marca `language` correctamente.
#    - **Reviews sin aspectos claros**: Incluye un aspecto genérico "experiencia general" con `sentiment` igual al general.
#    - **Reviews con ironía/sarcasmo**: Usa `sentiment` basado en el tono implícito (ej: "¡Qué maravilla!" → `1`).
#    - **Reviews con múltiples productos**: Prioriza el producto principal mencionado en el título o primeras líneas.
#
# 4. **Formato de Salida:**
#    ```json
#    {
#      "reviews_analysis": [
#        {
#          "review_id": "R12345",
#          "product_id": "P67890",
#          "sentiment": 4,
#          "aspects_mentioned": [
#            {
#              "aspect": "precio",
#              "sentiment": 2,
#              "text_evidence": "El precio es abusivo para lo que ofrece.",
#              "is_improvement": true
#            },
#            {
#              "aspect": "calidad",
#              "sentiment": 5,
#              "text_evidence": "El producto es excelente en calidad.",
#              "is_improvement": false
#            }
#          ],
#          "satisfaction_score": 7,
#          "recommendations": [
#            {
#              "issue": "Revisar política de precios",
#              "aspect_related": "precio",
#              "priority": "alta",
#              "quote": "El precio es abusivo para lo que ofrece."
#            }
#          ],
#          "metadata": {
#            "language": "es",
#            "review_length": 12
#          }
#        }
#      ],
#      "summary": {
#        "total_reviews": 1,
#        "avg_sentiment": 4.0,
#        "top_aspects": ["calidad", "precio"],
#        "top_recommendations": ["Revisar política de precios"]
#      }
#    }
#    ```
#
# ---
#
# ### **Ejemplos de Entrada/Salida:**
#
# #### **Ejemplo 1: Review Positiva**
# **Entrada:**
# `"Me encanta este producto, es de muy buena calidad y el envío fue rápido. Lo recomiendo al 100%."`
#
# **Salida:**
# ```json
# {
#   "reviews_analysis": [
#     {
#       "review_id": "R54321",
#       "product_id": "P11223",
#       "sentiment": 5,
#       "aspects_mentioned": [
#         {
#           "aspect": "calidad",
#           "sentiment": 5,
#           "text_evidence": "es de muy buena calidad",
#           "is_improvement": false
#         },
#         {
#           "aspect": "envío",
#           "sentiment": 5,
#           "text_evidence": "el envío fue rápido",
#           "is_improvement": false
#         }
#       ],
#       "satisfaction_score": 10,
#       "recommendations": [],
#       "metadata": {
#         "language": "es",
#         "review_length": 15
#       }
#     }
#   ]
# }
# ```
#
# #### **Ejemplo 2: Review Negativa con Ironía**
# **Entrada:**
# `"¡Fantástico! Llegó roto después de 2 semanas de espera. El servicio al cliente es una broma."`
#
# **Salida:**
# ```json
# {
#   "reviews_analysis": [
#     {
#       "review_id": "R67890",
#       "product_id": "P45678",
#       "sentiment": 1,
#       "aspects_mentioned": [
#         {
#           "aspect": "calidad",
#           "sentiment": 1,
#           "text_evidence": "Llegó roto",
#           "is_improvement": true
#         },
#         {
#           "aspect": "envío",
#           "sentiment": 1,
#           "text_evidence": "2 semanas de espera",
#           "is_improvement": true
#         },
#         {
#           "aspect": "servicio",
#           "sentiment": 1,
#           "text_evidence": "El servicio al cliente es una broma",
#           "is_improvement": true
#         }
#       ],
#       "satisfaction_score": 2,
#       "recommendations": [
#         {
#           "issue": "Mejorar embalaje y tiempos de entrega",
#           "aspect_related": "envío",
#           "priority": "alta",
#           "quote": "Llegó roto después de 2 semanas de espera"
#         },
#         {
#           "issue": "Capacitar al equipo de atención al cliente",
#           "aspect_related": "servicio",
#           "priority": "alta",
#           "quote": "El servicio al cliente es una broma"
#         }
#       ],
#       "metadata": {
#         "language": "es",
#         "review_length": 18
#       }
#     }
#   ]
# }
# ```
#
# ---
#
# ### **Notas Adicionales:**
# - **Precisión:** Prioriza la exactitud en la detección de aspectos y sentimiento sobre la exhaustividad.
# - **Consistencia:** Usa la misma escala de sentimiento (`1-5`) en todos los campos.
# - **Flexibilidad:** Si un aspecto no está mencionado explícitamente, omítelo (no lo inventes).
# - **Idiomas:** Soporte para español (prioritario), pero incluye `language` para otros idiomas.
#
# ---
#
# Este prompt garantiza **resultados estructurados y accionables** para el análisis de reviews, con un equilibrio entre profundidad y eficiencia. ¿Necesitas ajustar algún aspecto?
#
# === PROBANDO EL PROMPT GENERADO ===
# Review de prueba: Producto llegó rápido y bien empaquetado. La calidad es buena por el precio
#         que pagué (25€), aunque esperaba que fuera un poco más resistente. El servicio al cliente
#         respondió rápido cuando tuve una duda. Lo recomendaría para uso ocasional.
# RESULTADO DEL ANÁLISIS:
# ```json
# {
#   "reviews_analysis": [
#     {
#       "review_id": "R78901",
#       "product_id": "P12345",
#       "sentiment": 4,
#       "aspects_mentioned": [
#         {
#           "aspect": "envío",
#           "sentiment": 5,
#           "text_evidence": "Producto llegó rápido y bien empaquetado",
#           "is_improvement": false
#         },
#         {
#           "aspect": "calidad",
#           "sentiment": 4,
#           "text_evidence": "La calidad es buena por el precio que pagué",
#           "is_improvement": true
#         },
#         {
#           "aspect": "resistencia",
#           "sentiment": 3,
#           "text_evidence": "aunque esperaba que fuera un poco más resistente",
#           "is_improvement": true
#         },
#         {
#           "aspect": "servicio",
#           "sentiment": 5,
#           "text_evidence": "El servicio al cliente respondió rápido cuando tuve una duda",
#           "is_improvement": false
#         },
#         {
#           "aspect": "experiencia general",
#           "sentiment": 4,
#           "text_evidence": "Lo recomendaría para uso ocasional",
#           "is_improvement": false
#         }
#       ],
#       "satisfaction_score": 8,
#       "recommendations": [
#         {
#           "issue": "Mejorar la resistencia del producto para uso más intensivo",
#           "aspect_related": "resistencia",
#           "priority": "media",
#           "quote": "aunque esperaba que fuera un poco más resistente"
#         }
#       ],
#       "metadata": {
#         "language": "es",
#         "review_length": 35
#       }
#     }
#   ],
#   "summary": {
#     "total_reviews": 1,
#     "avg_sentiment": 4.0,
#     "top_aspects": ["envío", "calidad", "servicio"],
#     "top_recommendations": ["Mejorar la resistencia del producto para uso más intensivo"]
#   }
# }
# ```
#
# === EVALUACIÓN DEL PROMPT GENERADO ===
# ✓ Sentimiento: No
# ✓ Aspectos: Sí
# ✓ Puntuacion: Sí
# ✓ Estructura: Sí
# ✓ Recomendaciones: Sí
#
# ✓ Efectividad del meta-prompt: 4/5 elementos
# ✓ Calidad: Excelente

# %% [markdown]
# ## 5. Prompt Chaining
#
# Prompt chaining conecta múltiples prompts en secuencia, donde la salida de uno alimenta al siguiente.

# %%
def prompt_chaining_ejemplo():
    print("=== PROMPT CHAINING ===")
    
    # Tarea compleja que se beneficia de descomposición
    documento_entrada = """Nuestra empresa SaaS ha experimentado un crecimiento del 150% en usuarios 
    este año, pero los ingresos solo crecieron 80%. El churn rate aumentó de 5% a 12%. 
    Los costos de infraestructura se triplicaron. El equipo de soporte está saturado 
    con 3x más tickets. Los usuarios se quejan de lentitud y bugs. El equipo de desarrollo 
    está al 200% de capacidad. Necesitamos un plan estratégico para los próximos 6 meses."""
    
    print("DOCUMENTO DE ENTRADA:")
    print(documento_entrada)
    print("\n=== INICIANDO CADENA DE PROMPTS ===")
    
    # PASO 1: Análisis de problemas
    prompt_1 = f"""Analiza este reporte empresarial e identifica los problemas principales:
    
{documento_entrada}
    
Extrae y categoriza los problemas en:
1. FINANCIEROS (ingresos, costos, etc.)
2. OPERACIONALES (procesos, capacidad, etc.)
3. TÉCNICOS (rendimiento, bugs, etc.)
4. RECURSOS HUMANOS (capacidad del equipo, etc.)
    
Para cada problema, indica:
- Descripción del problema
- Gravedad (Alta/Media/Baja)
- Impacto en el negocio
    
Análisis de problemas:"""
    
    try:
        response_1 = llm.invoke([HumanMessage(content=prompt_1)])
        analisis_problemas = response_1.content
        
        print("\n📊 PASO 1 - ANÁLISIS DE PROBLEMAS:")
        print(analisis_problemas[:300] + "...")
        
        # PASO 2: Priorización usando resultado del paso 1
        prompt_2 = f"""Basándote en este análisis de problemas, crea una matriz de priorización:
        
ANÁLISIS PREVIO:
{analisis_problemas}
        
Crea una matriz de priorización considerando:
- IMPACTO en el negocio (Alto/Medio/Bajo)
- URGENCIA temporal (Inmediato/Corto plazo/Medio plazo)
- ESFUERZO requerido (Alto/Medio/Bajo)
        
Ordena los problemas por prioridad de atención y explica el criterio.
        
Matriz de priorización:"""
        
        response_2 = llm.invoke([HumanMessage(content=prompt_2)])
        priorizacion = response_2.content
        
        print("\n🎯 PASO 2 - PRIORIZACIÓN:")
        print(priorizacion[:300] + "...")
        
        # PASO 3: Plan de acción usando resultados anteriores
        prompt_3 = f"""Usando este análisis y priorización, desarrolla un plan de acción detallado:
        
ANÁLISIS DE PROBLEMAS:
{analisis_problemas[:500]}...
        
PRIORIZACIÓN:
{priorizacion[:500]}...
        
Desarrolla un plan estratégico de 6 meses que incluya:
        
MES 1-2 (ACCIONES INMEDIATAS):
- Iniciativas críticas
- Recursos necesarios
- Métricas de éxito
        
MES 3-4 (MEJORAS ESTRUCTURALES):
- Proyectos de mediano plazo
- Inversiones requeridas
        
MES 5-6 (OPTIMIZACIÓN):
- Consolidación y refinamiento
- Preparación para crecimiento
        
Plan estratégico:"""
        
        response_3 = llm.invoke([HumanMessage(content=prompt_3)])
        plan_accion = response_3.content
        
        print("\n📋 PASO 3 - PLAN DE ACCIÓN:")
        print(plan_accion[:400] + "...")
        
        # PASO 4: Métricas y KPIs usando toda la información anterior
        # Calcular el número de categorías fuera de la f-string
        num_categorias = len(analisis_problemas.split('\n'))
        
        prompt_4 = f"""Basándote en todo el análisis previo, define métricas y KPIs para monitorear el progreso:
        
CONTEXTO COMPLETO:
- Problemas identificados: {num_categorias} categorías
- Priorización establecida
- Plan de 6 meses definido
        
Define:
        
MÉTRICAS PRINCIPALES (North Star):
- 2-3 métricas clave que reflejen el éxito general
        
KPIs OPERACIONALES:
- Métricas específicas por área (financiera, técnica, operacional)
- Targets cuantitativos para 3 y 6 meses
        
DASHBOARD DE SEGUIMIENTO:
- Frecuencia de medición
- Responsables
- Alertas tempranas
        
Sistema de métricas:"""
        
        response_4 = llm.invoke([HumanMessage(content=prompt_4)])
        metricas = response_4.content
        
        print("\n📈 PASO 4 - MÉTRICAS Y KPIs:")
        print(metricas[:400] + "...")
        
        # Análisis de la efectividad del chaining
        print(f"\n=== ANÁLISIS DEL PROMPT CHAINING ===")
        
        # Verificar progresión lógica
        pasos_completados = 4
        informacion_acumulada = len(analisis_problemas) + len(priorizacion) + len(plan_accion) + len(metricas)
        
        # Verificar coherencia entre pasos
        coherencia_elementos = [
            'problema' in plan_accion.lower(),  # Plan referencia problemas
            'prioridad' in plan_accion.lower(),  # Plan usa priorización
            'mes' in metricas.lower(),  # Métricas alineadas con timeline
            'kpi' in metricas.lower() or 'métrica' in metricas.lower()  # Define métricas específicas
        ]
        
        coherencia = sum(coherencia_elementos)
        
        print(f"✓ Pasos completados: {pasos_completados}/4")
        print(f"✓ Información total generada: ~{informacion_acumulada} caracteres")
        print(f"✓ Coherencia entre pasos: {coherencia}/4 elementos")
        print(f"✓ Efectividad del chaining: {'Excelente' if coherencia >= 3 else 'Buena' if coherencia >= 2 else 'Necesita mejoras'}")
        
        # Beneficios del chaining observados
        print(f"\n✓ Beneficios observados:")
        print(f"  • Descomposición de problema complejo")
        print(f"  • Construcción incremental de solución")
        print(f"  • Cada paso informa al siguiente")
        print(f"  • Resultado final más completo y estructurado")
        
    except Exception as e:
        print(f"Error en prompt chaining: {e}")

# Ejecutar Prompt Chaining
prompt_chaining_ejemplo()
# Out:
# === PROMPT CHAINING ===
# DOCUMENTO DE ENTRADA:
# Nuestra empresa SaaS ha experimentado un crecimiento del 150% en usuarios
#     este año, pero los ingresos solo crecieron 80%. El churn rate aumentó de 5% a 12%.
#     Los costos de infraestructura se triplicaron. El equipo de soporte está saturado
#     con 3x más tickets. Los usuarios se quejan de lentitud y bugs. El equipo de desarrollo
#     está al 200% de capacidad. Necesitamos un plan estratégico para los próximos 6 meses.
#
# === INICIANDO CADENA DE PROMPTS ===
# 📊 PASO 1 - ANÁLISIS DE PROBLEMAS:
# ### **Análisis de Problemas en la Empresa SaaS**
#
# #### **1. PROBLEMAS FINANCIEROS**
# | **Problema** | **Descripción** | **Gravedad** | **Impacto en el Negocio** |
# |--------------|----------------|--------------|---------------------------|
# | **Desacople entre crecimiento de usuarios e ingresos** | Cr...
# 🎯 PASO 2 - PRIORIZACIÓN:
# Aquí tienes la **matriz de priorización** basada en los criterios de **Impacto en el Negocio**, **Urgencia temporal** y **Esfuerzo requerido**, ordenando los problemas por prioridad de atención:
#
# ---
#
# ### **Matriz de Priorización**
# *(Ordenada de mayor a menor prioridad)*
#
# | **Prioridad** | **Problem...
# 📋 PASO 3 - PLAN DE ACCIÓN:
# ### **Plan Estratégico de 6 Meses para Resolver los Problemas Financieros y Estructurales en la Empresa SaaS**
# **Objetivo General:**
# Alinear el crecimiento de usuarios con la monetización, mejorar la eficiencia operativa y sentar las bases para un modelo de ingresos sostenible.
#
# ---
#
# ## **📌 MES 1-2: ACCIONES INMEDIATAS**
# **Enfoque:** Mitigar riesgos financieros, ajustar modelos de monetización y m...
# 📈 PASO 4 - MÉTRICAS Y KPIs:
# Aquí tienes una propuesta estructurada de **métricas y KPIs** para monitorear el progreso del plan de 6 meses, alineada con el contexto de **46 categorías problemáticas priorizadas** y el enfoque en mejora continua. Las métricas se dividen en **North Star (éxito global)**, **KPIs operacionales (áreas clave)** y un **dashboard de seguimiento**.
#
# ---
#
# ## **1. Métricas Principales (North Star)**
# **Ob...
#
# === ANÁLISIS DEL PROMPT CHAINING ===
# ✓ Pasos completados: 4/4
# ✓ Información total generada: ~24798 caracteres
# ✓ Coherencia entre pasos: 3/4 elementos
# ✓ Efectividad del chaining: Excelente
#
# ✓ Beneficios observados:
#   • Descomposición de problema complejo
#   • Construcción incremental de solución
#   • Cada paso informa al siguiente
#   • Resultado final más completo y estructurado

# %% [markdown]
# # Comparación de Técnicas Avanzadas
#
# Resumen de cuándo usar cada técnica avanzada.
#
# ## Matriz Comparativa
#
# | Técnica | Complejidad | Costo | Tiempo | Precisión | Uso Ideal |
# |---------|-------------|-------|---------|-----------|-----------|
# | **Tree of Thoughts** | Alta | Muy Alto | Alto | Muy Alta | Decisiones complejas con múltiples caminos posibles |
# | **Self-Consistency** | Media | Alto | Alto | Muy Alta | Problemas donde la confiabilidad es crítica |
# | **Program-Aided** | Media | Medio | Medio | Muy Alta | Problemas que requieren cálculos precisos |
# | **Meta-Prompting** | Media | Medio | Medio | Alta | Cuando necesitas optimizar prompts automáticamente |
# | **Prompt Chaining** | Alta | Alto | Alto | Alta | Problemas complejos que se descomponen en pasos |
#
# ## 🎯 Guía de Selección
#
# ### 🔍 Para EXPLORAR ALTERNATIVAS
# - **Usa:** Tree of Thoughts
# - **Cuándo:** Cuando hay múltiples caminos válidos
#
# ### 🎯 Para MÁXIMA CONFIABILIDAD
# - **Usa:** Self-Consistency
# - **Cuándo:** Cuando los errores son costosos
#
# ### 🧮 Para CÁLCULOS PRECISOS
# - **Usa:** Program-Aided
# - **Cuándo:** Cuando necesitas exactitud matemática
#
# ### ⚙️ Para OPTIMIZAR PROMPTS
# - **Usa:** Meta-Prompting
# - **Cuándo:** Cuando necesitas automatizar prompt design
#
# ### 🔗 Para PROBLEMAS COMPLEJOS
# - **Usa:** Prompt Chaining
# - **Cuándo:** Cuando el problema se puede descomponer
#
# ## 💡 Recomendaciones de Implementación
#
# 1. **EMPIEZA SIMPLE:** Prueba técnicas básicas antes de avanzadas
# 2. **MIDE COSTOS:** Las técnicas avanzadas consumen más tokens
# 3. **VALIDA RESULTADOS:** Siempre verifica la calidad de salida
# 4. **COMBINA TÉCNICAS:** Puedes usar múltiples enfoques complementarios
# 5. **AUTOMATIZA:** Considera scripts para técnicas que usarás frecuentemente

# %% [markdown]
# ## Ejercicio Integrador
#
# Aplicar múltiples técnicas avanzadas a un problema empresarial complejo.

# %%
# Ejercicio final: Caso integrador
def ejercicio_integrador():
    print("=== EJERCICIO INTEGRADOR: TÉCNICAS AVANZADAS ===")
    
    caso_complejo = """CASO: EXPANSIÓN INTERNACIONAL DE STARTUP
    
    TechFlow, una startup española de software de gestión de proyectos, tiene:
    - 50,000 usuarios activos (70% España, 20% LATAM, 10% resto)
    - ARR de 2.4M€, crecimiento 180% anual
    - Equipo de 25 personas (15 desarrollo, 5 ventas, 5 ops)
    - Funding Serie A de 5M€ recientemente cerrada
    
    DESAFÍO: Decidir estrategia de expansión internacional para los próximos 18 meses.
    
    OPCIONES CONSIDERADAS:
    1. Europa (Francia, Italia, Alemania) - mercado similar, regulación conocida
    2. USA - mercado grande, competencia intensa, regulación compleja
    3. LATAM (México, Colombia, Chile) - afinidad cultural, menor poder adquisitivo
    4. Consolidación España - dominar mercado local antes de expandir
    
    RESTRICCIONES:
    - Presupuesto: 1.5M€ para expansión
    - Tiempo: Decisión debe tomarse en 2 meses
    - Recursos: Solo puede abrir 1-2 mercados simultáneamente
    - Regulación: Debe cumplir GDPR y regulaciones locales"""
    
    print(caso_complejo)
    
    print("\n🎯 EJERCICIO PROPUESTO:")
    print("\nDiseña una estrategia de análisis usando MÚLTIPLES técnicas avanzadas:")
    
    estrategia_sugerida = """
    PASO 1: META-PROMPTING
    - Genera prompts optimizados para analizar cada mercado objetivo
    
    PASO 2: PROGRAM-AIDED ANALYSIS  
    - Calcula métricas financieras: TAM, CAC, LTV por mercado
    - Proyecciones de revenue y costos de entrada
    
    PASO 3: TREE OF THOUGHTS
    - Explora sistemáticamente pros/contras de cada opción
    - Considera factores: mercado, competencia, recursos, timing
    
    PASO 4: SELF-CONSISTENCY
    - Genera múltiples recomendaciones con diferentes enfoques
    - Identifica consenso o áreas de incertidumbre
    
    PASO 5: PROMPT CHAINING
    - Integra todos los análisis anteriores
    - Desarrolla plan de implementación detallado
    - Define timeline, milestones y métricas de éxito
    """
    
    print(estrategia_sugerida)
    
    print("\n💡 TU IMPLEMENTACIÓN:")
    print("\n1. Elige 2-3 técnicas que consideres más apropiadas para este caso")
    print("2. Diseña los prompts específicos para cada técnica")
    print("3. Ejecuta tu análisis")
    print("4. Compara resultados entre técnicas")
    print("5. Proporciona recomendación final integrada")
    
    # Template para implementación del estudiante
    template_implementacion = """
    # IMPLEMENTACIÓN DEL ESTUDIANTE
    
    ## TÉCNICAS SELECCIONADAS:
    1. [Técnica 1]: [Justificación]
    2. [Técnica 2]: [Justificación] 
    3. [Técnica 3]: [Justificación]
    
    ## PROMPTS DISEÑADOS:
    
    ### Prompt para [Técnica 1]:
    [Tu prompt aquí]
    
    ### Prompt para [Técnica 2]:
    [Tu prompt aquí]
    
    ## ANÁLISIS COMPARATIVO:
    [Compara resultados entre técnicas]
    
    ## RECOMENDACIÓN FINAL:
    [Tu recomendación integrada]
    """
    
    print(template_implementacion)
    
    # Criterios de evaluación
    print("\n📋 CRITERIOS DE EVALUACIÓN:")
    criterios = [
        "✓ Selección apropiada de técnicas para el problema",
        "✓ Calidad y estructura de los prompts diseñados", 
        "✓ Profundidad del análisis realizado",
        "✓ Integración efectiva de múltiples perspectivas",
        "✓ Practicidad y viabilidad de la recomendación final"
    ]
    
    for criterio in criterios:
        print(f"   {criterio}")
    
    print("\n🏆 OBJETIVO: Demostrar dominio de técnicas avanzadas aplicadas a casos reales")

# Ejecutar ejercicio integrador
ejercicio_integrador()
# Out:
# === EJERCICIO INTEGRADOR: TÉCNICAS AVANZADAS ===
# CASO: EXPANSIÓN INTERNACIONAL DE STARTUP
#
#     TechFlow, una startup española de software de gestión de proyectos, tiene:
#     - 50,000 usuarios activos (70% España, 20% LATAM, 10% resto)
#     - ARR de 2.4M€, crecimiento 180% anual
#     - Equipo de 25 personas (15 desarrollo, 5 ventas, 5 ops)
#     - Funding Serie A de 5M€ recientemente cerrada
#
#     DESAFÍO: Decidir estrategia de expansión internacional para los próximos 18 meses.
#
#     OPCIONES CONSIDERADAS:
#     1. Europa (Francia, Italia, Alemania) - mercado similar, regulación conocida
#     2. USA - mercado grande, competencia intensa, regulación compleja
#     3. LATAM (México, Colombia, Chile) - afinidad cultural, menor poder adquisitivo
#     4. Consolidación España - dominar mercado local antes de expandir
#
#     RESTRICCIONES:
#     - Presupuesto: 1.5M€ para expansión
#     - Tiempo: Decisión debe tomarse en 2 meses
#     - Recursos: Solo puede abrir 1-2 mercados simultáneamente
#     - Regulación: Debe cumplir GDPR y regulaciones locales
#
# 🎯 EJERCICIO PROPUESTO:
#
# Diseña una estrategia de análisis usando MÚLTIPLES técnicas avanzadas:
#
#     PASO 1: META-PROMPTING
#     - Genera prompts optimizados para analizar cada mercado objetivo
#
#     PASO 2: PROGRAM-AIDED ANALYSIS
#     - Calcula métricas financieras: TAM, CAC, LTV por mercado
#     - Proyecciones de revenue y costos de entrada
#
#     PASO 3: TREE OF THOUGHTS
#     - Explora sistemáticamente pros/contras de cada opción
#     - Considera factores: mercado, competencia, recursos, timing
#
#     PASO 4: SELF-CONSISTENCY
#     - Genera múltiples recomendaciones con diferentes enfoques
#     - Identifica consenso o áreas de incertidumbre
#
#     PASO 5: PROMPT CHAINING
#     - Integra todos los análisis anteriores
#     - Desarrolla plan de implementación detallado
#     - Define timeline, milestones y métricas de éxito
#
#
# 💡 TU IMPLEMENTACIÓN:
#
# 1. Elige 2-3 técnicas que consideres más apropiadas para este caso
# 2. Diseña los prompts específicos para cada técnica
# 3. Ejecuta tu análisis
# 4. Compara resultados entre técnicas
# 5. Proporciona recomendación final integrada
#
#     # IMPLEMENTACIÓN DEL ESTUDIANTE
#
#     ## TÉCNICAS SELECCIONADAS:
#     1. [Técnica 1]: [Justificación]
#     2. [Técnica 2]: [Justificación]
#     3. [Técnica 3]: [Justificación]
#
#     ## PROMPTS DISEÑADOS:
#
#     ### Prompt para [Técnica 1]:
#     [Tu prompt aquí]
#
#     ### Prompt para [Técnica 2]:
#     [Tu prompt aquí]
#
#     ## ANÁLISIS COMPARATIVO:
#     [Compara resultados entre técnicas]
#
#     ## RECOMENDACIÓN FINAL:
#     [Tu recomendación integrada]
#
#
# 📋 CRITERIOS DE EVALUACIÓN:
#    ✓ Selección apropiada de técnicas para el problema
#    ✓ Calidad y estructura de los prompts diseñados
#    ✓ Profundidad del análisis realizado
#    ✓ Integración efectiva de múltiples perspectivas
#    ✓ Practicidad y viabilidad de la recomendación final
#
# 🏆 OBJETIVO: Demostrar dominio de técnicas avanzadas aplicadas a casos reales

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Tree of Thoughts** permite exploración sistemática de alternativas
# 2. **Self-Consistency** mejora confiabilidad mediante múltiples caminos
# 3. **Program-Aided Language Models** combinan razonamiento LLM + precisión código
# 4. **Meta-Prompting** automatiza la optimización de prompts
# 5. **Prompt Chaining** descompone problemas complejos en pasos manejables
#
# ## Cuándo Usar Cada Técnica
#
# ### 🎯 Matriz de Decisión:
# - **Alta precisión requerida** → Self-Consistency + PAL
# - **Múltiples alternativas** → Tree of Thoughts
# - **Problema complejo** → Prompt Chaining
# - **Automatización** → Meta-Prompting
# - **Cálculos críticos** → Program-Aided
#
# ### ⚖️ Trade-offs:
# - **Precisión vs. Costo**: Técnicas avanzadas son más precisas pero más costosas
# - **Complejidad vs. Control**: Mayor control requiere mayor complejidad de implementación
# - **Tiempo vs. Calidad**: Mejores resultados requieren más tiempo de procesamiento
#
# ### Para Practicar:
# 1. Implementa cada técnica en tu dominio específico
# 2. Combina múltiples técnicas para problemas complejos
# 3. Mide y compara efectividad vs. costo
# 4. Desarrolla templates reutilizables para tu uso frecuente
